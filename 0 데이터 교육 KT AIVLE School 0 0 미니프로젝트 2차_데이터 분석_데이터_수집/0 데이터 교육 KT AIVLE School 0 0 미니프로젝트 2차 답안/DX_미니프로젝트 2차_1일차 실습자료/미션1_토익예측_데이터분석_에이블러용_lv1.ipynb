# %% [markdown]
# # **Mission_1 토익 점수 데이터 분석**

# %% [markdown]
# ## <미션>

# %% [markdown]
# 최종 차수 점수 변화(Score_diff_total)와 feature들간의 관계를 분석하기 위한 가설 검증 수행
# * 전처리 단계에서 생성한 데이터에 대한 탐색적 데이터 분석을 수행해봅시다.
# * 개별 변수 및 개별 변수들 간의 관계에 대해 분석합니다.
# * [도전 미션] 새로운 변수를 추가하여 데이터에 대한 탐색적 데이터 분석을 수행해봅시다.

# %% [markdown]
# ## <환경설정>

# %% [markdown]
# ### &nbsp;&nbsp; 1) 라이브러리 불러오기

# %% [markdown]
# * **세부 요구사항**
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드가 작성되어 있습니다.
#     - 필요하다고 판단되는 라이브러리를 추가하세요.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as spst

# 아래 필요한 라이브러리, 함수를 추가하시오.
## 코드 입력

# %% [markdown]
# ### &nbsp;&nbsp; 2) 한글 폰트 설정하기

# %%
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### &nbsp;&nbsp; 3) 데이터 불러오기
#     * toeic_preprocessed_data.csv

# %%
file = 'toeic_preprocessed_data.csv'
## 코드 입력
base_data =

# %% [markdown]
# <br><br><hr>

# %% [markdown]
# ## 1. 기본 분석

# %% [markdown]
#   - 데이터프레임의 크기를 확인
#   - 데이터프레임의 컬럼명과 컬렴별 데이터 개수, 데이터 타입을 확인
#   - 데이터프레임 전체에 대한 기초통계량 확인
#   - 결측치(NaN) 확인
#     * 결측치(NaN)가 존재한다면 적절하게 조치합니다.

# %% [markdown]
# #### &nbsp;&nbsp; 1-1) 데이터프레임 크기 확인

# %%
## shape 
## 코드 입력
# Out:
# (500, 20)

# %% [markdown]
# #### &nbsp;&nbsp; 1-2) 컬럼명, 데이터 개수, 데이터 타입 확인

# %%
## info
## 코드 입력
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                500 non-null    int64
#  1   Gender            500 non-null    object
#  2   Birth_Year        500 non-null    int64
#  3   3rd_LC_Score      500 non-null    int64
#  4   3rd_RC_Score      500 non-null    int64
#  5   3rd_Total_Score   500 non-null    int64
#  6   학습목표              500 non-null    object
#  7   학습방법              500 non-null    object
#  8   강의 학습 교재 유형       500 non-null    object
#  9   학습빈도              500 non-null    object
#  10  기출문제 공부 횟수        500 non-null    int64
#  11  취약분야 인지 여부        500 non-null    object
#  12  토익 모의테스트 횟수       500 non-null    int64
#  13  1st_LC_Score      500 non-null    int64
#  14  1st_RC_Score      500 non-null    int64
#  15  1st_Total_Score   500 non-null    int64
#  16  2nd_LC_Score      500 non-null    int64
#  17  2nd_RC_Score      500 non-null    int64
#  18  2nd_Total_Score   500 non-null    int64
#  19  Score_diff_total  500 non-null    int64
# dtypes: int64(14), object(6)
# memory usage: 78.3+ KB

# %% [markdown]
# #### &nbsp;&nbsp; 1-3) 기초통계량 확인

# %%
## describe
## 코드 입력
# Out:
#                ID   Birth_Year  3rd_LC_Score  3rd_RC_Score  3rd_Total_Score  \
# count  500.000000   500.000000    500.000000    500.000000       500.000000
# mean   250.500000  1992.906000    368.240000    369.518000       737.798000
# std    144.481833     8.224381     82.135393     81.665858       155.901584
# min      1.000000  1973.000000    141.000000    135.000000       280.000000
# 25%    125.750000  1986.750000    295.000000    295.000000       591.750000
# 50%    250.500000  1992.500000    372.500000    375.000000       760.500000
# 75%    375.250000  2000.000000    434.250000    437.250000       860.250000
# max    500.000000  2007.000000    495.000000    495.000000       990.000000
#
#        기출문제 공부 횟수  토익 모의테스트 횟수  1st_LC_Score  1st_RC_Score  1st_Total_Score  \
# count  500.000000   500.000000    500.000000    500.000000        500.00000
# mean     5.098000     9.460000    313.878000    312.822000        626.70000
# std      2.779901     4.955554     85.555611     86.574966        148.57171
# min      1.000000     1.000000    105.000000     84.000000        250.00000
# 25%      3.000000     5.000000    259.750000    250.000000        519.00000
# 50%      5.000000     8.000000    308.000000    311.500000        642.00000
# 75%      7.000000    13.250000    369.250000    377.250000        735.00000
# max     10.000000    20.000000    495.000000    491.000000        970.00000
#
#        2nd_LC_Score  2nd_RC_Score  2nd_Total_Score  Score_diff_total
# count    500.000000    500.000000       500.000000        500.000000
# mean     338.120000    338.154000       676.284000         61.514000
# std       84.169535     83.854382       153.178624         39.739051
# min      120.000000    129.000000       260.000000          0.000000
# 25%      279.000000    281.500000       557.750000         30.000000
# 50%      333.500000    335.000000       691.000000         63.000000
# 75%      395.250000    400.000000       790.500000         83.000000
# max      495.000000    495.000000       990.000000        281.000000

# %% [markdown]
# #### &nbsp;&nbsp; 1-4) 결측치(N/A) 개수 확인

# %%
## 결측치 포함 여부 : isna
## 코드 입력
# Out:
# ID                  0
# Gender              0
# Birth_Year          0
# 3rd_LC_Score        0
# 3rd_RC_Score        0
# 3rd_Total_Score     0
# 학습목표                0
# 학습방법                0
# 강의 학습 교재 유형         0
# 학습빈도                0
# 기출문제 공부 횟수          0
# 취약분야 인지 여부          0
# 토익 모의테스트 횟수         0
# 1st_LC_Score        0
# 1st_RC_Score        0
# 1st_Total_Score     0
# 2nd_LC_Score        0
# 2nd_RC_Score        0
# 2nd_Total_Score     0
# Score_diff_total    0
# dtype: int64

# %% [markdown]
# <br><br><hr>

# %% [markdown]
# ## 2. 단변량 분석

# %% [markdown]
# - 주요 변수들의 분포를 살펴보며 비즈니스를 파악합시다.
# - 단일 변수로 분석
#     * 숫자형 변수 : 기초통계량, 히스토그램, kdeplot, 박스플롯
#     * 범주형 변수 : 범주별 빈도수, 바 플롯

# %% [markdown]
# #### &nbsp;&nbsp; 2-1) 최종 차수 점수 변화(Score_diff_total)

# %%
## 'Score_diff_total' 변수의 기초통계량 확인 .T를 활용해서 한줄로 표현
## 코드 입력

plt.figure(figsize = (12,8))

plt.subplot(2,1,1)
## 'Score_diff_total' 변수의 histplot그리기
## 코드 입력
sns.histplot()
plt.grid()

plt.subplot(2,1,2)

## 'Score_diff_total' 변수의 boxplot 그리기
## 코드 입력
sns.boxplot()

plt.grid()

plt.show()
# Out:
#                   count    mean        std  min   25%   50%   75%    max
# Score_diff_total  500.0  61.514  39.739051  0.0  30.0  63.0  83.0  281.0

# %%
## 'Score_diff_total' 변수의 kdeplot 그리기
## 코드 입력

sns.kdeplot(   )

plt.grid()

plt.show()

# %% [markdown]
# #### &nbsp;&nbsp; 2-2) 범주형 변수
#    * 분석 방법 : 범주별 빈도수, countplot
#    * 대상 변수 : Gender, 학습목표, 학습방법, 강의 학습 교재 유형, 학습빈도, 취약분야 인지 여부

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 2-2-1) 'Gender'

# %%
## 범주형 변수의 범주별 빈도수 확인하기 : value_counts()
## 코드 입력


## 범주형 변수의 범주별 빈도 비율 확인하기 : value_counts() / df.shape[0]
## 코드 입력


plt.figure(figsize=(8, 5))
## 그래프 분석하기 : countplot()
## 코드 입력
sns.countplot()

plt.title('Gender 현황')
plt.grid()
# plt.show()
# Out:
# M    250
# F    250
# Name: Gender, dtype: int64
# M    0.5
# F    0.5
# Name: Gender, dtype: float64

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 2-2-2) 학습목표

# %%
## 범주형 변수의 범주별 빈도수 확인하기 : value_counts()
## 코드 입력

## 범주형 변수의 범주별 빈도 비율 확인하기 : value_counts() / df.shape[0]
## 코드 입력



plt.figure(figsize=(8, 5))
## 그래프 분석하기 : countplot()
## 코드 입력
sns.countplot()

plt.title('학습목표 현황')
plt.grid()
# plt.show()
# Out:
# 자기계발    329
# 승진      155
# 취업       16
# Name: 학습목표, dtype: int64
# 자기계발    0.658
# 승진      0.310
# 취업      0.032
# Name: 학습목표, dtype: float64

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 2-2-3) 학습방법

# %%
## 범주형 변수의 범주별 빈도수 확인하기 : value_counts()
## 코드 입력

## 범주형 변수의 범주별 빈도 비율 확인하기 : value_counts() / df.shape[0]
## 코드 입력


plt.figure(figsize=(8, 5))
## 그래프 분석하기 : countplot()
## 코드 입력
sns.countplot()

plt.title('학습방법 현황')
plt.grid()
plt.show()
# Out:
# 온라인강의     208
# 오프라인강의    162
# 참고서       130
# Name: 학습방법, dtype: int64
# 온라인강의     0.416
# 오프라인강의    0.324
# 참고서       0.260
# Name: 학습방법, dtype: float64

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 2-2-4) 강의 학습 교재 유형

# %%
## 범주형 변수의 범주별 빈도수 확인하기 : value_counts()
## 코드 입력

## 범주형 변수의 범주별 빈도 비율 확인하기 : value_counts() / df.shape[0]
## 코드 입력

plt.figure(figsize=(8, 5))
## 그래프 분석하기 : countplot()
## 코드 입력
sns.countplot()


plt.title('강의 학습 교재 유형 현황')
plt.grid()
plt.show()
# Out:
# 일반적인 영어 텍스트 기반 교재        136
# 영상 교재                    128
# 뉴스/이슈 기반 교재              122
# 비즈니스 시뮬레이션(Role Play)    114
# Name: 강의 학습 교재 유형, dtype: int64
# 일반적인 영어 텍스트 기반 교재        0.272
# 영상 교재                    0.256
# 뉴스/이슈 기반 교재              0.244
# 비즈니스 시뮬레이션(Role Play)    0.228
# Name: 강의 학습 교재 유형, dtype: float64

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 2-2-5) 학습빈도

# %%
## 범주형 변수의 범주별 빈도수 확인하기 : value_counts()
## 코드 입력


## 범주형 변수의 범주별 빈도 비율 확인하기 : value_counts() / df.shape[0]
## 코드 입력

plt.figure(figsize=(8, 5))
## 그래프 분석하기 : countplot()
## 코드 입력
sns.countplot()

plt.title('학습빈도 현황')
plt.grid()
plt.show()
# Out:
# 주3-4회       151
# 주5-6회       127
# 주1-2회       124
# 매일(주 7회)     98
# Name: 학습빈도, dtype: int64
# 주3-4회       0.302
# 주5-6회       0.254
# 주1-2회       0.248
# 매일(주 7회)    0.196
# Name: 학습빈도, dtype: float64

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 2-2-6) 취약분야 인지 여부

# %%
## 범주형 변수의 범주별 빈도수 확인하기 : value_counts()
## 코드 입력


## 범주형 변수의 범주별 빈도 비율 확인하기 : value_counts() / df.shape[0]
## 코드 입력


plt.figure(figsize=(8, 5))
## 그래프 분석하기 : countplot()
## 코드 입력
sns.countplot()

plt.title('취약분야 인지 여부 현황')
plt.grid()
plt.show()
# Out:
# 알고 있음       461
# 알고 있지 않음     39
# Name: 취약분야 인지 여부, dtype: int64
# 알고 있음       0.922
# 알고 있지 않음    0.078
# Name: 취약분야 인지 여부, dtype: float64

# %% [markdown]
# #### &nbsp;&nbsp; 2-3) 수치형 변수
#    * 분석 방법 : 기초 통계, 히스토그램, boxplot
#    * 대상 변수 : 'Birth_Year', '기출문제 공부 횟수','토익 모의테스트 횟수',  '1st_Total_Score', '2st_Total_Score'

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 2-3-1) Bitrh_Year

# %%
## 수치형 변수의 기초 통계량 확인 : describe
## 코드 입력


## 그래프 분석

plt.figure(figsize = (12,8))
plt.subplot(2,1,1)

## 히스토그램을 이용한 데이터 분포 확인
## 코드 입력
sns.histplot()

plt.grid()

plt.subplot(2,1,2)
## boxplot 이용한 데이터 분포 확인
## 코드 입력
sns.boxplot()

plt.grid()

plt.show()
# Out:
#             count      mean       std     min      25%     50%     75%     max
# Birth_Year  500.0  1992.906  8.224381  1973.0  1986.75  1992.5  2000.0  2007.0

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 2-3-2) 기출문제 공부 횟수

# %%
## 수치형 변수의 기초 통계량 확인 : describe
## 코드 입력


## 그래프 분석

plt.figure(figsize = (12,8))
plt.subplot(2,1,1)

## 히스토그램을 이용한 데이터 분포 확인
## 코드 입력
sns.histplot()

plt.grid()

plt.subplot(2,1,2)

## boxplot 이용한 데이터 분포 확인
## 코드 입력
sns.boxplot()

plt.grid()

plt.show()
# Out:
#             count   mean       std  min  25%  50%  75%   max
# 기출문제 공부 횟수  500.0  5.098  2.779901  1.0  3.0  5.0  7.0  10.0

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 2-3-3) 토익 모의테스트 횟수

# %%
## 수치형 변수의 기초 통계량 확인 : describe
## 코드 입력

## 그래프 분석
plt.figure(figsize = (12,8))

plt.subplot(2,1,1)
## 히스토그램을 이용한 데이터 분포 확인
## 코드 입력
sns.histplot()

plt.grid()

plt.subplot(2,1,2)
## boxplot 이용한 데이터 분포 확인
## 코드 입력
sns.boxplot()

plt.grid()

plt.show()
# Out:
#              count  mean       std  min  25%  50%    75%   max
# 토익 모의테스트 횟수  500.0  9.46  4.955554  1.0  5.0  8.0  13.25  20.0

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 2-3-4) 1st_Total_Score

# %%
## 수치형 변수의 기초 통계량 확인 : describe
## 코드 입력

## 그래프 분석
plt.figure(figsize = (12,8))
plt.subplot(2,1,1)

## 히스토그램을 이용한 데이터 분포 확인
## 코드 입력
sns.histplot()

plt.grid()

plt.subplot(2,1,2)
## boxplot 이용한 데이터 분포 확인
## 코드 입력
sns.boxplot()

plt.grid()

plt.show()
# Out:
#                  count   mean        std    min    25%    50%    75%    max
# 1st_Total_Score  500.0  626.7  148.57171  250.0  519.0  642.0  735.0  970.0

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 2-3-5) 2nd_Total_Score

# %%
## 수치형 변수의 기초 통계량 확인 : describe
## 코드 입력

## 그래프 분석
plt.figure(figsize = (12,8))

plt.subplot(2,1,1)
## 히스토그램을 이용한 데이터 분포 확인
## 코드 입력
sns.histplot()

plt.grid()

plt.subplot(2,1,2)
## boxplot 이용한 데이터 분포 확인
## 코드 입력
sns.boxplot()

plt.grid()

plt.show()
# Out:
#                  count     mean         std    min     25%    50%    75%  \
# 2nd_Total_Score  500.0  676.284  153.178624  260.0  557.75  691.0  790.5
#
#                    max
# 2nd_Total_Score  990.0

# %% [markdown]
# ## [정리] 단변량 분석을 통해 파악된 비즈니스 인사이트는 무엇인가요?

# %% [markdown]
# <br><br><hr><br><br>

# %% [markdown]
# ## 3. 이변량 분석

# %% [markdown]
# - 수치형 feature --> 수치형 target
#     - 전체 변수들 간의 상관관계 구하기
#         * 범주형 변수를 제외한 데이터셋을 이용하여
#         * .corr() + sns.heatmap() 으로 전체 상관계수를 시각화
#     - 상관계수 상위 몇개에 대해서 feature와 target에 대해
#         * 상관분석을 통해 상관계수가 유의미함을 분석
#         * 산점도를 통해 상관관계를 시각화하여 분석
# - 범주형 feature --> 수치형 target
#     * 범주간에 target의 평균의 차이가 있는지 분석
#     * 범주별 barplot으로 평균의 차이를 시각화하여 분석

# %% [markdown]
# #### &nbsp;&nbsp; 3-1) 수치형 feature --> 수치형 target

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 3-1-1) 전체 수치형 변수들 간의 상관관계 분석

# %% [markdown]
# * 수치형 변수 리스트 만들기

# %%
# 수치형 변수 리스트 정의

col_num = ['Birth_Year','3rd_LC_Score','3rd_RC_Score','3rd_Total_Score', '기출문제 공부 횟수','토익 모의테스트 횟수', '1st_LC_Score', '1st_RC_Score', '1st_Total_Score',
            '2nd_LC_Score', '2nd_RC_Score', '2nd_Total_Score', 'Score_diff_total']

# %%
## 수치형 변수들의 데이터 확인

base_data[col_num]
# Out:
#      Birth_Year  3rd_LC_Score  3rd_RC_Score  3rd_Total_Score  기출문제 공부 횟수  \
# 0          1973           345           336              681           7
# 1          1982           380           368              748           4
# 2          1995           416           382              798           4
# 3          1987           495           397              892           9
# 4          1994           398           437              835           6
# ..          ...           ...           ...              ...         ...
# 495        2006           364           336              700          10
# 496        1988           187           252              439           9
# 497        2006           255           167              422           2
# 498        1990           422           370              792           4
# 499        1984           235           226              461           7
#
#      토익 모의테스트 횟수  1st_LC_Score  1st_RC_Score  1st_Total_Score  2nd_LC_Score  \
# 0             10           181           173              354           227
# 1             14           330           290              620           354
# 2              4           367           309              676           396
# 3              8           470           285              755           495
# 4              4           273           372              645           314
# ..           ...           ...           ...              ...           ...
# 495           13           347           315              662           349
# 496           17           112           250              362           120
# 497            4           252           150              402           254
# 498            7           371           324              695           378
# 499           15           169           188              357           172
#
#      2nd_RC_Score  2nd_Total_Score  Score_diff_total
# 0             213              440               241
# 1             339              693                55
# 2             365              761                37
# 3             341              836                56
# 4             426              740                95
# ..            ...              ...               ...
# 495           321              670                30
# 496           251              371                68
# 497           158              412                10
# 498           326              704                88
# 499           190              362                99
#
# [500 rows x 13 columns]

# %% [markdown]
# * 숫자형 데이터의 상호 상관관계

# %%
## 데이터 프레임의 상관계수 도출하기 : corr
## 코드 입력
# Out:
#                   Birth_Year  3rd_LC_Score  3rd_RC_Score  3rd_Total_Score  \
# Birth_Year          1.000000      0.034871      0.027302         0.032645
# 3rd_LC_Score        0.034871      1.000000      0.810450         0.951776
# 3rd_RC_Score        0.027302      0.810450      1.000000         0.951058
# 3rd_Total_Score     0.032645      0.951776      0.951058         1.000000
# 기출문제 공부 횟수          0.000754      0.042070      0.035350         0.040950
# 토익 모의테스트 횟수        -0.010049      0.009477      0.012057         0.011285
# 1st_LC_Score        0.065178      0.892739      0.651576         0.812176
# 1st_RC_Score        0.051614      0.641789      0.892840         0.806150
# 1st_Total_Score     0.067610      0.888068      0.895484         0.937450
# 2nd_LC_Score        0.058882      0.951131      0.729434         0.883673
# 2nd_RC_Score        0.060268      0.725373      0.948760         0.879439
# 2nd_Total_Score     0.065340      0.919824      0.920256         0.967091
# Score_diff_total   -0.123791      0.188377      0.183897         0.195372
#
#                   기출문제 공부 횟수  토익 모의테스트 횟수  1st_LC_Score  1st_RC_Score  \
# Birth_Year          0.000754    -0.010049      0.065178      0.051614
# 3rd_LC_Score        0.042070     0.009477      0.892739      0.641789
# 3rd_RC_Score        0.035350     0.012057      0.651576      0.892840
# 3rd_Total_Score     0.040950     0.011285      0.812176      0.806150
# 기출문제 공부 횟수          1.000000     0.822999     -0.001871     -0.010960
# 토익 모의테스트 횟수         0.822999     1.000000     -0.020741     -0.035071
# 1st_LC_Score       -0.001871    -0.020741      1.000000      0.489982
# 1st_RC_Score       -0.010960    -0.035071      0.489982      1.000000
# 1st_Total_Score    -0.007464    -0.032380      0.861374      0.864873
# 2nd_LC_Score       -0.013591    -0.033481      0.951472      0.568388
# 2nd_RC_Score       -0.012960    -0.025364      0.569375      0.956994
# 2nd_Total_Score    -0.014495    -0.032288      0.834647      0.836292
# Score_diff_total    0.216523     0.168731     -0.030968     -0.060947
#
#                   1st_Total_Score  2nd_LC_Score  2nd_RC_Score  \
# Birth_Year               0.067610      0.058882      0.060268
# 3rd_LC_Score             0.888068      0.951131      0.725373
# 3rd_RC_Score             0.895484      0.729434      0.948760
# 3rd_Total_Score          0.937450      0.883673      0.879439
# 기출문제 공부 횟수              -0.007464     -0.013591     -0.012960
# 토익 모의테스트 횟수             -0.032380     -0.033481     -0.025364
# 1st_LC_Score             0.861374      0.951472      0.569375
# 1st_RC_Score             0.864873      0.568388      0.956994
# 1st_Total_Score          1.000000      0.879117      0.885532
# 2nd_LC_Score             0.879117      1.000000      0.661840
# 2nd_RC_Score             0.885532      0.661840      1.000000
# 2nd_Total_Score          0.967955      0.911918      0.911175
# Score_diff_total        -0.053348     -0.048322     -0.062073
#
#                   2nd_Total_Score  Score_diff_total
# Birth_Year               0.065340         -0.123791
# 3rd_LC_Score             0.919824          0.188377
# 3rd_RC_Score             0.920256          0.183897
# 3rd_Total_Score          0.967091          0.195372
# 기출문제 공부 횟수              -0.014495          0.216523
# 토익 모의테스트 횟수             -0.032288          0.168731
# 1st_LC_Score             0.834647         -0.030968
# 1st_RC_Score             0.836292         -0.060947
# 1st_Total_Score          0.967955         -0.053348
# 2nd_LC_Score             0.911918         -0.048322
# 2nd_RC_Score             0.911175         -0.062073
# 2nd_Total_Score          1.000000         -0.060585
# Score_diff_total        -0.060585          1.000000

# %% [markdown]
# * 상관계수 시각화

# %%
## 상관계수값을 heatmap을 이용하여 시각화 : sns.heatmap

plt.figure(figsize = (12,12))
## 코드 입력
sns.heatmap()

plt.show()

# %% [markdown]
# ### target과 상관계수 상위 3개 살펴보기

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 3-1-2) 기출문제 공부 횟수

# %%
## 가설 수립
## 귀무 가설(H0) :
## 대립 가설(H1) :

# %%
# 상관분석 (pearsonr)
## 코드 입력
spst.pearsonr(base_data['기출문제 공부 횟수'], base_data['Score_diff_total'])
# Out:
# PearsonRResult(statistic=0.21652328806766585, pvalue=1.020785279200108e-06)

# %%
# regplot으로 시각화
plt.figure(figsize = (12,8))
## 코드 입력
sns.regplot()

plt.grid()
plt.show()

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 3-1-3) 토익 모의테스트 횟수

# %%
## 가설 수립
## 귀무 가설(H0) :
## 대립 가설(H1) :

# %%
# 상관분석 (pearsonr)
## 코드 입력
# Out:
# PearsonRResult(statistic=0.16873093322890687, pvalue=0.00015021865019138392)

# %%
# regplot으로 시각화

plt.figure(figsize = (15,8))
## 코드 입력
sns.regplot()

plt.grid()
plt.show()

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 3-1-4) 2차 종합점수

# %%
## 가설 수립
## 귀무 가설(H0) :
## 대립 가설(H1) :

# %%
## 상관분석 (pearsonr)
## 코드 입력
# Out:
# PearsonRResult(statistic=-0.06058469921846522, pvalue=0.17619398209815046)

# %%
## regplot으로 시각화
plt.figure(figsize = (15,8))
## 코드 입력
sns.regplot()

plt.grid()
plt.show()

# %% [markdown]
# #### &nbsp;&nbsp; 3-2) 범주형 feature -> 수치형 target

# %%
## 범주형 feature

## 'Gender', '학습목표', '학습방법', '강의 학습 교재 유형', '학습빈도', '취약분야 인지 여부', 'age_group',

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 3-2-1) Gender

# %%
## 가설 수립
## 귀무 가설(H0) :
## 대립 가설(H1) :

# %%
## 그래프 분석 : barplot

plt.figure(figsize = (15,8))
## 코드 입력
sns.barplot()

plt.grid()
plt.show()

# %%
## 범주 데이터 확인 : value_counts()
## 코드 입력
# Out:
# M    250
# F    250
# Name: Gender, dtype: int64

# %%
## 평균 분석 : ttest_ind
## 코드 입력

t_male = 
t_female =
# Out:
# Ttest_indResult(statistic=0.2822086676965537, pvalue=0.7779007564857058)

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 3-2-2) 학습목표

# %%
## 가설 수립
## 귀무 가설(H0) :
## 대립 가설(H1) :

# %%
## 그래프 분석 : barplot

plt.figure(figsize = (15,8))
## 코드 입력
sns.barplot()

plt.grid()
plt.show()

# %%
## 범주 데이터 확인 : value_counts()
## 코드 입력
# Out:
# 자기계발    329
# 승진      155
# 취업       16
# Name: 학습목표, dtype: int64

# %%
## 분산 분석 : f_oneway
## 코드 입력

anova_1 = 
anova_2 = 
anova_3 =
# Out:
# F_onewayResult(statistic=47.67396089358833, pvalue=1.1460686383036893e-19)

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 3-2-3) 학습방법

# %%
## 가설 수립
## 귀무 가설(H0) :
## 대립 가설(H1) :

# %%
## 그래프 분석 : barplot

plt.figure(figsize = (15,8))
## 코드 입력
sns.barplot()

plt.grid()
plt.show()

# %%
## 범주 데이터 확인 : value_counts()
## 코드 입력
# Out:
# 온라인강의     208
# 오프라인강의    162
# 참고서       130
# Name: 학습방법, dtype: int64

# %%
## 분산 분석 : f_oneway()
## 코드 입력
anova_1 = 
anova_2 = 
anova_3 =
# Out:
# F_onewayResult(statistic=41.419201452370245, pvalue=2.3055747160060528e-17)

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 3-2-4) 강의 학습 교재 유형

# %%
## 가설 수립
## 귀무 가설(H0) :
## 대립 가설(H1) :

# %%
## 그래프 분석 : barplot

plt.figure(figsize = (15,8))
## 코드 입력
sns.barplot()


plt.grid()
plt.show()

# %%
## 범주 데이터 확인 : value_counts()
## 코드 입력
# Out:
# 일반적인 영어 텍스트 기반 교재        136
# 영상 교재                    128
# 뉴스/이슈 기반 교재              122
# 비즈니스 시뮬레이션(Role Play)    114
# Name: 강의 학습 교재 유형, dtype: int64

# %%
## 분산 분석 : f_oneway
## 코드 입력

anova_1 = 
anova_2 = 
anova_3 = 
anova_4 =
# Out:
# F_onewayResult(statistic=52.47853679755316, pvalue=1.7913087495809398e-29)

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 3-2-5) 학습빈도

# %%
## 가설 수립
## 귀무 가설(H0) :
## 대립 가설(H1) :

# %%
# 그래프 분석 : barplot

plt.figure(figsize = (15,8))
## 코드 입력
sns.barplot()

plt.grid()
plt.show()

# %%
## 범주 데이터 확인 : value_counts()
## 코드 입력
# Out:
# 주3-4회       151
# 주5-6회       127
# 주1-2회       124
# 매일(주 7회)     98
# Name: 학습빈도, dtype: int64

# %%
## 분산 분석 : f_oneway
## 코드 입력

anova_1 = 
anova_2 = 
anova_3 = 
anova_4 =
# Out:
# F_onewayResult(statistic=10.462186683951074, pvalue=1.1022320109042592e-06)

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 3-2-6) 취약분야 인지 여부

# %%
## 가설 수립
## 귀무 가설(H0) :
## 대립 가설(H1) :

# %%
## 그래프 분석 : barplot

plt.figure(figsize = (15,8))
## 코드 입력
sns.barplot()

plt.grid()
plt.show()

# %%
## 범주 데이터 확인 : value_counts
## 코드 입력
# Out:
# 알고 있음       461
# 알고 있지 않음     39
# Name: 취약분야 인지 여부, dtype: int64

# %%
## 평균 분석 : ttest_ind
## 코드 입력

t_yes = 
t_no =
# Out:
# Ttest_indResult(statistic=3.5228688483686006, pvalue=0.00046620434773948446)

# %% [markdown]
# ## [정리] 이변량 분석을 통해 파악된 비즈니스 인사이트는 무엇인가요?

# %% [markdown]
# <br><br><hr><br><br>

# %% [markdown]
# ## <font color="orange">**4. 도전 미션** </font>

# %% [markdown]
# #### &nbsp;&nbsp; 4-1)  나이, 나이대 정보 추가 및 데이터 분석

# %% [markdown]
#   - 생년월일을 나이로 변경하여 **열(age)**을 추가하세요.
#   - 나이로 변경한 열을 아래의 예시를 참고하여 연령대로 구분하여 **열(age group)**을 추가하세요.
#     - 연령 구분 예시 : 20세 이하, 21세-25세, 26세-30세, 31세-35세, 36세-40세, 41세-45세, 46세-50세, 50세 이상
#   - 나이, 나이대 데이터 특성에 맞는 단변량, 이변량 분석을 하세요.

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 4-1-1) 나이(age) 열 추가

# %%
# 라이브러리 불러오기
from datetime import datetime

# 현재 날짜 구하기
now = datetime.now()

# 데이터프레임에서 Birth_Year 열의 값으로부터 현재 날짜(2023년도) 기준 나이 계산 
# 'age'열에 값 추가하기
## 코드 입력

# 확인
base_data

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 4-1-2) 나이(age) 단변량 분석

# %%
## age 데이터의 기초 통계량 확인
## 코드 입력

## age 데이터 분포 시각화 확인
## 코드 입력

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 4-1-3) 나이대(age_group) 열 추가

# %%
## cut() 함수를 활용하여 나이 연령대 계산

## 각 나이 연령대 구간의 경계(bins) 정의
## 코드 입력
bins = 

## labels: 각 구간에 붙일 라벨
## 코드 입력
labels = 

## cut 함수 사용
## 코드 입력
base_data['age_group'] = 

## 데이터 확인
base_data

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 4-1-4) 나이대(age_group) 단변량 분석

# %%
## 범주형 변수의 범주별 빈도수 확인하기 : value_counts()
## 코드 입력


## 범주형 변수의 범주별 빈도 비율 확인하기 : value_counts() / df.shape[0]
## 코드 입력

# age_group 기준으로 데이터 분포 시각화 확인 : countplot()
## 코드 입력

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 4-1-5) 나이(age) -> Target 이변량 분석

# %%
## 가설 수립
## 귀무 가설(H0) :
## 대립 가설(H1) :

# %%
## 상관분석 (pearsonr)
## 코드 입력


## regplot으로 시각화
## 코드 입력

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 4-1-6) 나이대(age_group) -> Target 이변량 분석

# %%
## barplot 시각화
## 코드 입력

# %%
## 범주 데이터 확인
## 코드 입력

# %%
## 분산 분석 : f_oneway
## 코드 입력

# %% [markdown]
# #### &nbsp;&nbsp; 4-2) 1,2회차 점수 차이 정보 추가 및 데이터 분석

# %% [markdown]
# * **세부요구사항**
#     - 1,2회차 점수 차이 ( 2회차 점수 - 1회차 점수)를 구하여 **열(Score_diff_total_2_1)**을 추가하세요.
#     - 1,2회차 점수 차이 데이터 특성에 맞는 단변량, 이변량 분석을 하세요.

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 4-2-1) 1,2회 점수 차 (Score_diff_total_2_1) 열 추가

# %%
## 'Score_diff_total_2_1' = '2nd_Total_Score' - '1st_Total_Score'
## 코드 입력

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 4-2-2) Score_diff_total_2_1 단변량 분석

# %%
## Score_diff_total_2_1 데이터의 기초 통계량 확인
## 코드 입력

## Score_diff_total_2_1  데이터 분포 시각화 확인
## 코드 입력

# %% [markdown]
# ##### &nbsp; &nbsp; &nbsp; &nbsp; 4-2-3) Score_diff_2_1 -> Target 이변량 분석

# %%
## 상관분석 (pearsonr)
## 코드 입력

## regplot으로 시각화
## 코드 입력

# %% [markdown]
# #### &nbsp;&nbsp; 4-3) 추가하고 싶은 정보를 생성하고, 이에 대한 단변량/이변량 분석을 수행

# %%
## 열(데이터) 추가
## 코드 입력

# %%
## 단변량 분석

# 기초 통계량 확인
## 코드 입력


# 데이터 분포 시각화 확인
## 코드 입력

# %%
## 이변량 분석

# 상관분석 (pearsonr)
## 코드 입력

# regplot으로 시각화
## 코드 입력

# %% [markdown]
# ## [정리] 3가지 추가 feature를 통해 파악된 비즈니스 인사이트는 무엇인가요?

# %% [markdown]
# ## <font color="green"> **Mission Clear** </font> &nbsp; &nbsp; 수고하셨습니다!!
