# %% [markdown]
# # **토익진단평가 데이터 다듬기2**
# # 단계2 : 데이터프레임 탐색

# %% [markdown]
# ## 0.미션

# %% [markdown]
# * 전처리 단계에서 생성한 데이터에 대한 데이터프레임 탐색을 해봅시다.
# * 다양한 메소드와 속성을 사용해 데이터에 대해 살펴봅니다.
# * 메소드(head(), tail(), info(), describe())인지 속성(shape, index, values, columns)인지 파악하고 사용합니다.
# * 개별 변수 및 개별 변수들 간의 관계에 대해 생각해보고, 분석해봅니다.

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# ### (1) 폰트 설치

# %%
# 아래 라이브러리를 수행해주세요.
##[해설] matplotlib은 데이터 시각화를 위한 그래프 그리기 라이브러리입니다. 
##[해설] 아직 데이터 시각화를 배우지는 않으셨지만 간단한 그래프 한가지는 만들어보겠습니다.

# %%
# !pip install matplotlib
# !pip install --upgrade matplotlib

import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# ### (2) 라이브러리 불러오기

# %% [markdown]
# * **세부 요구사항**
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드를 작성하였습니다.
#     - pandas, numpy, matplotlib 라이브러리를 실행해주세요.

# %%
#[문제] pandas 라이브러리를 임포트하세요.

# %%
import pandas as pd

# %%
#[문제] numpy 라이브러리를 임포트하세요.
##[해설] numpy는 다차원 배열이나 행렬 연산을 하기 위해 필요한 라이브러리입니다.

# %%
import numpy as np

# %%
#[문제] matplotlib 라이브러리를 임포트하세요.
##[해설] 데이터 시각화를 위한 matplotlib 라이브러리를 실행합니다.

# %%
import matplotlib.pyplot as plt

# %%
#차트에 한글폰트 설정을 위해 아래 라이브러리를 실행해주세요.
##[해설] Matplotlib을 사용하여 그래프를 그릴 때 한국어 폰트를 사용하기 위한 설정을 변경하는 작업입니다. 맑은고딕 한글 글꼴을 지정하여 그래프에 한글을 표시할 수 있도록 했습니다.
##[해설] plt.rc() 함수는 그래프의 기본 스타일이나 설정을 변경하는 데 사용되며 폰트, 색상, 선스타일 등을 조정합니다.

# %%
plt.rc('font', family='Malgun Gothic')

# %% [markdown]
# ### (3) 데이터 불러오기
# * 1.데이터 전처리 단계에서 앞 시간에 생성한 데이터를 로딩합니다.
#     * data04_baseline.csv
# * 다음과 같이 데이터를 저장하여 불러와주세요.
#     * 주피터랩 수행
#         * 제공된 압축파일 '미프 1차_토익'을 다운받아 압축을 푼다.
#         * anaconda의 root directory(보통 C:\Users\<ID> 에 '미프 1차_토익' 폴더를 만들고, 복사해 넣습니다.
#         * '2.데이터_탐색_교육생용' 실습파일을 열어주세요.

# %% [markdown]
# #### 1) 주피터랩 수행

# %%
# '미프 1차_토익' 폴더에 필요한 파일들을 넣고, 본 파일을 열고 데이터를 읽어옵니다.

# %%
#[문제] '미프 1차_토익' 폴더에서 본 파일 '2.데이터_탐색_교육생용' 실습파일을 열어주세요.
##[해설] 현재 작업 중인 디렉토리를 기준으로 하는 상대경로로 불러와주시기 바랍니다. 왼쪽에 보이는 현재 위치를 기준으로 경로를 표기합니다.
##[해설] 상대경로는 path = '../미프 1차_토익'

# %% [markdown]
# #### 2) 저장된 데이터 읽어오기
# * [1.전처리] 단계에서 저장된 .csv 파일인 'data04_baseline.csv' 파일을 불러옵니다.
# * 불러 온 후에는 shape를 확인해 봅시다.
# * info(), describe() 메소드는 상당히 많은 정보를 보여주므로 탐색 시 필히 확인합니다.

# %%
#[문제] data04_baseline.csv 파일을 pd.read_csv 함수를 이용하여 읽고 data변수에 할당하세요.

# %%
# 읽어들일 파일명 : data04_baseline.csv
# Pandas read_csv 함수 활용
# 결과 : data 저장

# %%
data = pd.read_csv('data04_baseline.csv')

# %%
#[문제] 읽어온 데이터프레임 data 확인해주세요.

# %%
data
# Out:
#        ID Gender  Birth_Year  Seq  3st_LC_Score  3st_RC_Score  \
# 0       1      M        1973  3.0         345.0         336.0
# 1       1      M        1973  3.0         345.0         336.0
# 2       1      M        1973  3.0         345.0         336.0
# 3       1      M        1973  3.0         345.0         336.0
# 4       1      M        1973  3.0         345.0         336.0
# ...   ...    ...         ...  ...           ...           ...
# 4480  500      M        1984  3.0         235.0         226.0
# 4481  500      M        1984  3.0         235.0         226.0
# 4482  500      M        1984  3.0         235.0         226.0
# 4483  500      M        1984  3.0         235.0         226.0
# 4484  500      M        1984  3.0         235.0         226.0
#
#       3st_Total_Score 학습목표    학습방법            강의 학습 교재 유형  ... 기출문제 공부 횟수  \
# 0               681.0   승진   온라인강의                  영상 교재  ...        7.0
# ...

# %%
#[문제] data 데이터프레임의 열과 행을 확인해주세요.
##[해설] shape 함수는 데이터의 행, 열 개수를 확인할 때 사용됩니다. shape 함수는 괄호()를 사용하지 않으니 주의하세요.

# %%
print(data.shape)
# Out:
# (4485, 21)

# %%
#[문제] data 데이터프레임의 자료구조(Row, Column, Not-null, type)을 파악하세요.
##[해설] info : 데이터의 열 수나 열 이름, 데이터 타입(int 정수, float 소수점, object 객체), 메모리 사용량 등을 확인

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4485 entries, 0 to 4484
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                4485 non-null   int64
#  1   Gender            4485 non-null   object
#  2   Birth_Year        4485 non-null   int64
#  3   Seq               4477 non-null   float64
#  4   3st_LC_Score      4477 non-null   float64
#  5   3st_RC_Score      4477 non-null   float64
#  6   3st_Total_Score   4477 non-null   float64
#  7   학습목표              4477 non-null   object
#  8   학습방법              4477 non-null   object
#  9   강의 학습 교재 유형       4477 non-null   object
#  10  학습빈도              4477 non-null   object
#  11  기출문제 공부 횟수        4477 non-null   float64
#  12  취약분야 인지 여부        4477 non-null   object
#  13  토익 모의테스트 횟수       4477 non-null   float64
#  14  1st_LC_Score      4481 non-null   float64
#  15  1st_RC_Score      4481 non-null   float64
# ...

# %%
#[문제] 인덱스를 확인해보세요.
##[해설] 데이터의 고유한 식별자인 인덱스가 0부터 시작하고 1500 미만까지 범위를 가지고, step=1은 인덱스간 간격이 1씩 차이가 난다는 뜻입니다.
##[해설] index나 shape, columns와 같이 데이터프레임의 속성과 같은 정보는 함수처럼 호출되지 않고 ()를 쓰지 않고 정보를 가져옵니다.

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4485, step=1)

# %%
#[문제] 컬럼명을 확인해보세요.
##[해설] 데이터프레임 열(컬럼)에 대한 정보를 가져올 때는 columns 함수 사용. 이때 열 이름은 리스트로 반환되어 열 이름들을 확인할 수 있습니다.

# %%
data.columns
# Out:
# Index(['ID', 'Gender', 'Birth_Year', 'Seq', '3st_LC_Score', '3st_RC_Score',
#        '3st_Total_Score', '학습목표', '학습방법', '강의 학습 교재 유형', '학습빈도', '기출문제 공부 횟수',
#        '취약분야 인지 여부', '토익 모의테스트 횟수', '1st_LC_Score', '1st_RC_Score',
#        '1st_Total_Score', '2st_LC_Score', '2st_RC_Score', '2st_Total_Score',
#        'Score_diff_total'],
#       dtype='object')

# %%
#[문제] 상단 5행을 확인해보세요

# %%
data.head(5)
# Out:
#    ID Gender  Birth_Year  Seq  3st_LC_Score  3st_RC_Score  3st_Total_Score  \
# 0   1      M        1973  3.0         345.0         336.0            681.0
# 1   1      M        1973  3.0         345.0         336.0            681.0
# 2   1      M        1973  3.0         345.0         336.0            681.0
# 3   1      M        1973  3.0         345.0         336.0            681.0
# 4   1      M        1973  3.0         345.0         336.0            681.0
#
#   학습목표   학습방법 강의 학습 교재 유형  ... 기출문제 공부 횟수  취약분야 인지 여부 토익 모의테스트 횟수  \
# 0   승진  온라인강의       영상 교재  ...        7.0       알고 있음        10.0
# 1   승진  온라인강의       영상 교재  ...        7.0       알고 있음        10.0
# 2   승진  온라인강의       영상 교재  ...        7.0       알고 있음        10.0
# 3   승진  온라인강의       영상 교재  ...        7.0       알고 있음        10.0
# 4   승진  온라인강의       영상 교재  ...        7.0       알고 있음        10.0
#
#    1st_LC_Score  1st_RC_Score  1st_Total_Score  2st_LC_Score  2st_RC_Score  \
# ...

# %% [markdown]
# ## 2.데이터프레임 탐색 : 개별 변수 분석하기

# %% [markdown]
# * **세부 요구사항**
#     * 기본 분석
#         * 기초 통계량, NaN 값 확인 등 기본 분석을 수행합니다.
#         * 특정범위 열 조회(A~C 열 조회) : data.loc[:, 'A':'C'].head(), 범위 마지막 열도 조회 대상 포함
#     * 주요 변수들의 분포를 살펴보기
#         * 숫자형 변수 : 기초통계량 조회 (평균, 중앙값, 표준편차 등)
#         * 범주형 변수 : 특정한 카테고리나 범주로 구성된 변수인 범주별 빈도수, 바 플롯 (예시 : 성별, 혈액형, 지역 등 그룹화할 수 있는 변수)
#         * 시각화나 통계분석에서 범주형 변수의 그룹 간의 차이나 관계를 분석할 때 중요한 역할을 합니다.

# %% [markdown]
# ### (1) 기본 분석

# %% [markdown]
# * **세부 요구사항**
#     - 데이터프레임 전체에 대한 기초통계량을 구합니다.
#     - NaN을 확인해봅니다. (NaN = Not a Number, 수치가 아닌 값)
#       * NaN이 존재한다면 Numpy 모듈에서 isna() 함수를 통해 판별하고 적절하게 조치해줍니다.

# %%
#[문제] 'data'의 각 열별 누락된 값(Nan, none) 개수를 확인해보세요.
##[해설] isna 함수로 누락된 값 여부를 표시하고, 그 결과를 sum 함수를 이용하여 열마다 누락된 값의 개수를 합산합니다. nan값이 없고 정수 데이터입니다.
##[해설] nan값이 없음을 확인할 수 있습니다.

# %%
#isna() 함수 활용
data.isna().sum()
# Out:
# ID                  0
# Gender              0
# Birth_Year          0
# Seq                 8
# 3st_LC_Score        8
# 3st_RC_Score        8
# 3st_Total_Score     8
# 학습목표                8
# 학습방법                8
# 강의 학습 교재 유형         8
# 학습빈도                8
# 기출문제 공부 횟수          8
# 취약분야 인지 여부          8
# 토익 모의테스트 횟수         8
# 1st_LC_Score        4
# 1st_RC_Score        4
# 1st_Total_Score     4
# 2st_LC_Score        0
# 2st_RC_Score        0
# 2st_Total_Score     0
# Score_diff_total    8
# dtype: int64

# %%
#[문제] 'data'의 각 열 통계량을 요약하여 출력하세요.
##[해설] describe 함수는 데이터의 분포, 최소값, 최대값 등 통계 정보를 한눈에 파악할 수 있도록 도와주는 유용한 함수입니다.
##[해설] 개수, 평균, 표준편차(std), 최소값, 각 열별 백분위수, 최대값을 보여줍니다.

# %%
# describe 함수 활용
data.describe()
# Out:
#                ID   Birth_Year     Seq  3st_LC_Score  3st_RC_Score  \
# count  4485.00000  4485.000000  4477.0   4477.000000   4477.000000
# mean    249.67447  1992.878930     3.0    368.611124    370.114586
# std     143.88566     8.205072     0.0     81.969943     81.184212
# min       1.00000  1973.000000     3.0    141.000000    135.000000
# 25%     125.00000  1986.000000     3.0    295.000000    296.000000
# 50%     250.00000  1992.000000     3.0    373.000000    376.000000
# 75%     374.00000  2000.000000     3.0    435.000000    438.000000
# max     500.00000  2007.000000     3.0    495.000000    495.000000
#
#        3st_Total_Score   기출문제 공부 횟수  토익 모의테스트 횟수  1st_LC_Score  1st_RC_Score  \
# count      4477.000000  4477.000000  4477.000000   4481.000000   4481.000000
# mean        738.765915     5.113692     9.482689    313.935952    313.074760
# std         155.257612     2.774724     4.953039     85.541078     86.463191
# ...

# %%
#[문제] 위에서 출력한 통계량 데이터프레임의 행과 열을 서로 바꾸어 출력하세요.
##[해설] T는 데이터프레임의 기초통계량을 전치하여 출력하는 코드입니다. T를 추가하면 결과를 행과 열을 바꾸어 출력합니다.

# %%
#'T'는 데이터프레임의 전치(Transpose)를 의미함
# descibe 함수 활용
data.describe().T
# Out:
#                    count         mean         std     min     25%     50%  \
# ID                4485.0   249.674470  143.885660     1.0   125.0   250.0
# Birth_Year        4485.0  1992.878930    8.205072  1973.0  1986.0  1992.0
# Seq               4477.0     3.000000    0.000000     3.0     3.0     3.0
# 3st_LC_Score      4477.0   368.611124   81.969943   141.0   295.0   373.0
# 3st_RC_Score      4477.0   370.114586   81.184212   135.0   296.0   376.0
# 3st_Total_Score   4477.0   738.765915  155.257612   280.0   593.0   761.0
# 기출문제 공부 횟수        4477.0     5.113692    2.774724     1.0     3.0     5.0
# 토익 모의테스트 횟수       4477.0     9.482689    4.953039     1.0     5.0     9.0
# 1st_LC_Score      4481.0   313.935952   85.541078   105.0   260.0   308.0
# 1st_RC_Score      4481.0   313.074760   86.463191    84.0   250.0   312.0
# 1st_Total_Score   4481.0   627.010712  148.415249   250.0   519.0   643.0
# 2st_LC_Score      4485.0   340.226310   86.818994   105.0   279.0   335.0
# ...

# %%
#[문제] Gender 컬럼의 값 별 개수를 확인해주세요. (Gender M : 남자, F : 여자)
##[해설] value_counts()는 고유한 값의 등장 횟수를 세는 역할을 하는 메서드, dropna=True 지정 또는 생략하면 Nan값 제외
##[해설] 범주형 데이터의 분포를 파악하는데 유용하고, 각 범주의 빈도를 확인하면서 데이터를 이해할 수 있습니다.

# %%
# value_counts 함수 활용
data['Gender'].value_counts()
# Out:
# M    2245
# F    2240
# Name: Gender, dtype: int64

# %%
#[문제] 'Gender' 컬럼의 ['M', 'F'] --> [1,2]로 변경해해보세요.
##[해설] 특정 값을 다른 값으로 교체할 때 replace() 함수를 사용. 데이터 정제나 변환 작업에서 자주 활용됩니다. inplace=True를 통해 바로 원본 데이터프레임에 적용합니다.
##[해설] replace(['교체할 리스트'], ['교체하는 리스트'], inplace=True)로 코드를 작성합니다.
##[해설] replace()는 값들을 변경하는 데 사용, rename()은 열 또는 인덱스의 이름을 변경

# %%
# replace 함수 활용
data['Gender'].replace(['M', 'F'], [1,2], inplace=True)

# %%
#[문제] Gender 컬럼의 값 별 개수를 다시 확인해주세요.
##[해설] value_counts()는 고유한 값의 등장 횟수를 세는 역할을 하는 메서드입니다.
##[해설] 범주형 데이터의 분포를 파악하는데 유용하고, 각 범주의 빈도를 확인하면서 데이터를 이해할 수 있습니다.

# %%
data['Gender'].value_counts()
# Out:
# 1    2245
# 2    2240
# Name: Gender, dtype: int64

# %%
#[문제] 'Gender' 컬럼 타입을 object에서 int로 변경해보세요.
##[해설] 수치적 연산과 데이터 처리를 위해 문자열(object) 데이터에서 숫자형(int)으로 변경합니다. 
##[해설] astype() 함수는 데이터 타입을 변경하는 메서드입니다.
##[해설] 데이터 타입 : int 정수, float 소수점데이터, object 객체데이터

# %%
#astype 함수 활용

data['Gender'].astype(int)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4480    1
# 4481    1
# 4482    1
# 4483    1
# 4484    1
# Name: Gender, Length: 4485, dtype: int32

# %%
#[문제] data 데이터 프레임에서 Null 데이터가 있는지 확인해주세요.
##[해설] Null : 존재하지 않는 값, 아무런 값을 가지지 않는 것
##[해설] isnull 함수로 누락된 값 여부를 표시하고, 그 결과를 sum 함수를 이용하여 열마다 누락된 값의 개수를 합산합니다. 
##[해설] null값이 없는 정수 데이터입니다.

# %%
data.isnull().sum()
# Out:
# ID                  0
# Gender              0
# Birth_Year          0
# Seq                 8
# 3st_LC_Score        8
# 3st_RC_Score        8
# 3st_Total_Score     8
# 학습목표                8
# 학습방법                8
# 강의 학습 교재 유형         8
# 학습빈도                8
# 기출문제 공부 횟수          8
# 취약분야 인지 여부          8
# 토익 모의테스트 횟수         8
# 1st_LC_Score        4
# 1st_RC_Score        4
# 1st_Total_Score     4
# 2st_LC_Score        0
# 2st_RC_Score        0
# 2st_Total_Score     0
# Score_diff_total    8
# dtype: int64

# %% [markdown]
# ### (2) 주요 변수의 분포를 살펴보기

# %% [markdown]
# * **세부 요구사항**
#     - 주요 변수들의 분포를 살펴보자.
#         * 대상 : 최종 차수 점수 변화, 생년월일, 학습목표, 학습방법, 강의 학습 교재 유형
#         * 도구 : 기초통계량, bar차트를 통한 데이터 분포 파악
#     - 전체 현황과 각 변수별 현황을 비교해보고 결과를 저장하자.

# %% [markdown]
# #### 1) 열 데이터 탐색 및 시각화 : 최종 차수 점수 변화(Score_diff_total)

# %%
#[문제] 변수 Sdt에 문자열 'Score_diff_total'을 할당 하세요.

# %%
Sdt = 'Score_diff_total'

# %%
#[문제] 'data' 데이터프레임의 'Score_diff_total'열에 대한 기술 통계 정보를 데이터 프레임의 형태로 출력해주세요.
##[해설] 특정열인 Sdt라는 변수명을 선택하는 대괄호를 사용하고, 열을 선택하는 인덱싱 연산을 하는 대괄호를 2번 넣어줍니다.

# %%
# discribe() 함수 활용
data[[Sdt]].describe()
# Out:
#        Score_diff_total
# count       4477.000000
# mean          57.624972
# std           59.846821
# min            0.000000
# 25%            0.000000
# 50%           50.000000
# 75%           96.000000
# max          348.000000

# %%
#[문제] 위에서 추출한 데이터의 'Score_diff_total'에 대해 행과 열을 변환하여 기술 통계 정보를 출력해주세요.
##[해설] T는 데이터프레임의 기초통계량을 전치하여 출력하는 코드입니다. T를 추가하면 결과를 행과 열을 바꾸어 출력합니다.

# %%
# describe().T 함수 활용
data[[Sdt]].describe().T
# Out:
#                    count       mean        std  min  25%   50%   75%    max
# Score_diff_total  4477.0  57.624972  59.846821  0.0  0.0  50.0  96.0  348.0

# %% [markdown]
# #### 2) 열 추가 : Bitrh_Year
# * 출생연도로 부터 나이 변수를 추출해 봅시다. (나이 : 2016-Birth_Year)
# * 필요에 따라 matlotlib은 다양한 옵션을 제공, 다양한 형태의 bar 차트 생성 가능
# * plt.bar(cartegories, values)
# * plt.title('제목')
# * plt.xlabel('Categories')
# * plt.ylabel('Values')

# %%
#[문제] 변수 BY에 문자열 'Birth_Year'을 할당하세요.

# %%
BY = 'Birth_Year'

# %%
#[추가문제] 출생연도로부터 나이를 구해서 'Age'라는 열을 맨 뒤에 추가해주세요.

# %%
data['Age'] = 2016-data['Birth_Year']
data
# Out:
#        ID  Gender  Birth_Year  Seq  3st_LC_Score  3st_RC_Score  \
# 0       1       1        1973  3.0         345.0         336.0
# 1       1       1        1973  3.0         345.0         336.0
# 2       1       1        1973  3.0         345.0         336.0
# 3       1       1        1973  3.0         345.0         336.0
# 4       1       1        1973  3.0         345.0         336.0
# ...   ...     ...         ...  ...           ...           ...
# 4480  500       1        1984  3.0         235.0         226.0
# 4481  500       1        1984  3.0         235.0         226.0
# 4482  500       1        1984  3.0         235.0         226.0
# 4483  500       1        1984  3.0         235.0         226.0
# 4484  500       1        1984  3.0         235.0         226.0
#
#       3st_Total_Score 학습목표    학습방법            강의 학습 교재 유형  ... 취약분야 인지 여부  \
# 0               681.0   승진   온라인강의                  영상 교재  ...      알고 있음
# ...

# %%
#[문제] 'data' 데이터프레임의 'Birth_Year'열에 대한 기술 통계 정보를 출력해주세요.
# 'Birth_Year'에 대해 행과 열을 변환하여 기술 통계 정보를 출력해주세요.

# %%
# describe().T 함수 활용
data[[BY]].describe().T
# Out:
#              count        mean       std     min     25%     50%     75%  \
# Birth_Year  4485.0  1992.87893  8.205072  1973.0  1986.0  1992.0  2000.0
#
#                max
# Birth_Year  2007.0

# %%
#[문제] 'data' 데이터프레임의 'Birth_Year' 컬럼의 연도별 개수를 Bar 차트로 그리세요.
##[해설] 'BY'열의 값을 계산하려면 date[BY]의 value_counts()함수로 횟수를 세고, plot(kind=bar)으로 막대그래프 생성
##[해설] sort_index() 메서드를 사용, 생일년도를 오름차순으로 정렬(기본값은 ascending=True, 오름차순)

# %%
# DataFrame value_counts()와 plot() 함수 활용
# 대상 컬럼 : 'Birth_Year'
# plot 함수의 인자 : kind='bar'

data[BY].value_counts().sort_index(ascending=True).plot(kind='bar', x='BY', y='Values')
# Out:
# <Axes: >

# %%
# 또 다른 방법으로 Bar 차트 생성
# plt.xticks(':X축의 눈금을 설정하는 함수, unique() 메서드는 컬럼의 고유한 값들을 반환, 즉 X축의 틱 위치가 
# 연도 데이터의 고유한 값들로 설정, 텍스트가 겹치지 않도록 rotation=90 설정

plt.bar(data[BY].value_counts().index, data[BY].value_counts().values)
plt.xticks(ticks=data[BY].unique(), rotation=90)
plt.title('Birth Year 차트')
plt.xlabel('Birth Year')
plt.ylabel('Count')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### 3) 고유값 확인 : 컬럼 출력

# %%
#[문제] data 데이터프레임에서 object 컬럼에 대해서만 추출해서 보여주세요.
##[해설] 특정 데이터타입을 가진 열을 선택하는 함수는 select_dtypes 입니다. 이 함수로 원하는 데이터 타입을 가진 열만을 추출할 수 있습니다.

# %%
# select_dtypes() 함수 활용
data.select_dtypes('object')
# Out:
#      학습목표    학습방법            강의 학습 교재 유형   학습빈도 취약분야 인지 여부
# 0      승진   온라인강의                  영상 교재  주5-6회      알고 있음
# 1      승진   온라인강의                  영상 교재  주5-6회      알고 있음
# 2      승진   온라인강의                  영상 교재  주5-6회      알고 있음
# 3      승진   온라인강의                  영상 교재  주5-6회      알고 있음
# 4      승진   온라인강의                  영상 교재  주5-6회      알고 있음
# ...   ...     ...                    ...    ...        ...
# 4480   승진  오프라인강의  비즈니스 시뮬레이션(Role Play)  주5-6회      알고 있음
# 4481   승진  오프라인강의  비즈니스 시뮬레이션(Role Play)  주5-6회      알고 있음
# 4482   승진  오프라인강의  비즈니스 시뮬레이션(Role Play)  주5-6회      알고 있음
# 4483   승진  오프라인강의  비즈니스 시뮬레이션(Role Play)  주5-6회      알고 있음
# 4484   승진  오프라인강의  비즈니스 시뮬레이션(Role Play)  주5-6회      알고 있음
#
# [4485 rows x 5 columns]

# %%
#[문제] 데이터 타입이 Object 형태인 컬럼의 컬럼명만 추출해서 출력해 보세요.
##[해설] select_dtypes('object')로 문자열 데이터타입을 가진 열만 선택하고 '.columns'로 컬럼명을 가져오고 '.values'로 컬럼명을 넘파이 행렬로 가져옵니다.

# %%
# columns.values 활용
data.select_dtypes('object').columns.values
# Out:
# array(['학습목표', '학습방법', '강의 학습 교재 유형', '학습빈도', '취약분야 인지 여부'], dtype=object)

# %% [markdown]
# #### 4) 고유값 확인 및 시각화 : 학습목표

# %%
#[문제] 변수 '학습목표'의 값들의 빈도수를 계산하여 출력하세요.
##[해설] value_counts()는 고유한 값의 등장 횟수를 세는 역할을 하는 메서드입니다. 범주형 데이터의 분포를 파악하는데 유용하고, 각 범주의 빈도를 확인하면서 데이터를 이해할 수 있습니다.

# %%
# value_counts 함수 활용
print(data['학습목표'].value_counts())
# Out:
# 자기계발    2938
# 승진      1395
# 취업       144
# Name: 학습목표, dtype: int64

# %%
#[문제] data 데이터프레임의 전체 열과 행 개수를 각각 출력해 보세요.
##[해설] 첫번째 값은 행의 개수, 두번째 값은 열의 개수를 나타냅니다. 1은 튜플에서 두번째 요소(열의 개수)를 가져오는 인덱싱 연산입니다. 0은 첫번째 요소(행의 개수)를 가져옵니다.
##[해설] 튜플은 데이터 구조로 변경이 필요하지 않은 데이터값입니다.

# %%
#열의 개수
data.shape[1]
# Out:
# 22

# %%
#행의 개수
data.shape[0]
# Out:
# 4485

# %%
#[문제] 변수 '학습목표'의 값들의 빈도수를 전체 데이터의 개수로 나누어서 해당 값들이 전체 데이터에서 차지하는 비율을 구하세요.
##[해설] '학습목표' 열에서 value_counts() 함수로 빈도를 계산하고, 이를 전체 데이터의 행의 개수로 나누어 비율을 구할 수 있습니다. 전체 행의 개수는 data.shape(0)으로 가져옵니다.

# %%
data['학습목표'].value_counts()/data.shape[0]
# Out:
# 자기계발    0.655072
# 승진      0.311037
# 취업      0.032107
# Name: 학습목표, dtype: float64

# %%
#[문제] '학습목표' 컬럼에 대한 Bar 차트를 확인해주세요.
##[해설] 데이터프레임의 '학습목표'열의 값을 계산하려면 value_counts()함수로 횟수를 세고, plot(kind=bar)를 통해 막대그래프로 시각화합니다.
##[해설] data['학습목표'].value_counts().plot(kind='bar', x='학습목표', y='Values', title = '학습목표 현황') 으로 작성할 수 있습니다.

# %%
# DataFrame value_counts()와 plot() 함수 활용
# 대상 컬럼 : '학습목표'
# plot 함수의 인자 : kind='bar'
data['학습목표'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#[문제] 'data' 전체 데이터프레임의 숫자형 컬럼, number 컬럼에 대해 검색해주세요.
##[해설] select_dtypes('number')로 숫자형 데이터타입을 가진 열만 선택하여 추출합니다.

# %%
data.select_dtypes('number')
# Out:
#        ID  Gender  Birth_Year  Seq  3st_LC_Score  3st_RC_Score  \
# 0       1       1        1973  3.0         345.0         336.0
# 1       1       1        1973  3.0         345.0         336.0
# 2       1       1        1973  3.0         345.0         336.0
# 3       1       1        1973  3.0         345.0         336.0
# 4       1       1        1973  3.0         345.0         336.0
# ...   ...     ...         ...  ...           ...           ...
# 4480  500       1        1984  3.0         235.0         226.0
# 4481  500       1        1984  3.0         235.0         226.0
# 4482  500       1        1984  3.0         235.0         226.0
# 4483  500       1        1984  3.0         235.0         226.0
# 4484  500       1        1984  3.0         235.0         226.0
#
#       3st_Total_Score  기출문제 공부 횟수  토익 모의테스트 횟수  1st_LC_Score  1st_RC_Score  \
# 0               681.0         7.0         10.0         181.0         173.0
# ...

# %% [markdown]
# #### 5) 고유값 확인 및 시각화 : 강의 학습 교재 유형

# %%
#[문제] 변수 '강의 학습 교재 유형'의 값들의 빈도수, 비율을 계산해서 출력해주세요.
##[해설] 빈도수 출력은 value_counts() 함수로 각 유형별로 빈도를 계산합니다. 이를 통해 어떤 유형의 교재가 가장 많은지 어떻게 분포되어 있는지 확인할 수 있습니다.
##[해설] 비율 출력은 '강의 학습 교재 유형' 열의 각 유형별 빈도를 전체 데이터의 개수인 행의 개수로 나누어 계산합니다.

# %%
# 빈도수 출력
print(data['강의 학습 교재 유형'].value_counts())
# Out:
# 일반적인 영어 텍스트 기반 교재        1215
# 영상 교재                    1143
# 뉴스/이슈 기반 교재              1098
# 비즈니스 시뮬레이션(Role Play)    1021
# Name: 강의 학습 교재 유형, dtype: int64

# %%
# 비율 출력
print(data['강의 학습 교재 유형'].value_counts()/data.shape[0])
# Out:
# 일반적인 영어 텍스트 기반 교재        0.270903
# 영상 교재                    0.254849
# 뉴스/이슈 기반 교재              0.244816
# 비즈니스 시뮬레이션(Role Play)    0.227648
# Name: 강의 학습 교재 유형, dtype: float64

# %%
#[문제] '취약분야 인지 여부' 문자열의 값을 '알고 있음' --> '1', '알고 있지 않음' -->'0'으로 변경하세요.
##[해설] 특정 값을 다른 값으로 교체할 때 replace() 함수를 사용합니다. 데이터 정제나 변환 작업에서 자주 활용됩니다.
##[해설] '알고 있음'은 1로, '알고 있지 않음'은 0으로 매핑하여 중괄호로 딕셔너리를 표현합니다.
##[해설] map() 메소드로도 범주형 값을 다른 값으로 변환 가능합니다.
##[해설] data['취약분야 인지 여부'] = data['취약분야 인지 여부'].map({'알고 있음':'1', '알고 있지 않음':'0'})

# %%
data['취약분야 인지 여부'].replace({'알고 있음': '1', '알고 있지 않음': '0'})
data
# Out:
#        ID  Gender  Birth_Year  Seq  3st_LC_Score  3st_RC_Score  \
# 0       1       1        1973  3.0         345.0         336.0
# 1       1       1        1973  3.0         345.0         336.0
# 2       1       1        1973  3.0         345.0         336.0
# 3       1       1        1973  3.0         345.0         336.0
# 4       1       1        1973  3.0         345.0         336.0
# ...   ...     ...         ...  ...           ...           ...
# 4480  500       1        1984  3.0         235.0         226.0
# 4481  500       1        1984  3.0         235.0         226.0
# 4482  500       1        1984  3.0         235.0         226.0
# 4483  500       1        1984  3.0         235.0         226.0
# 4484  500       1        1984  3.0         235.0         226.0
#
#       3st_Total_Score 학습목표    학습방법            강의 학습 교재 유형  ... 취약분야 인지 여부  \
# 0               681.0   승진   온라인강의                  영상 교재  ...      알고 있음
# ...

# %% [markdown]
# ## 데이터 저장

# %% [markdown]
# * **세부 요구사항**
#     * to_csv를 이용하여 전처리된 데이터셋을 저장하세요.
#     * 저장할 파일의 확장자는 .csv 입니다.

# %%
#[문제] 전처리된 데이터프레임 'data04_featured'를 CSV 파일로 저장합니다.
##[해설] to_csv 함수를 사용해서 데이터프레임의 내용을 CSV 파일로 저장해줍니다. index=False할 경우 인덱스 번호가 파일에 포함되지 않습니다. 인덱스가 특별히 고유한 식별자가 아니기 때문에
##[해설] 우리는 인덱스를 제외하고 데이터를 저장하겠습니다.

# %%
# 파일 : 'data04_featured.csv'
# to_csv 함수 활용
data.to_csv('data04_featured.csv', index=False)

# %%
#[문제] 파일이 잘 저장되었는지, 다시 한번 불러오고 확인해보세요.

# %%
pd.read_csv('data04_featured.csv')
# Out:
#        ID  Gender  Birth_Year  Seq  3st_LC_Score  3st_RC_Score  \
# 0       1       1        1973  3.0         345.0         336.0
# 1       1       1        1973  3.0         345.0         336.0
# 2       1       1        1973  3.0         345.0         336.0
# 3       1       1        1973  3.0         345.0         336.0
# 4       1       1        1973  3.0         345.0         336.0
# ...   ...     ...         ...  ...           ...           ...
# 4480  500       1        1984  3.0         235.0         226.0
# 4481  500       1        1984  3.0         235.0         226.0
# 4482  500       1        1984  3.0         235.0         226.0
# 4483  500       1        1984  3.0         235.0         226.0
# 4484  500       1        1984  3.0         235.0         226.0
#
#       3st_Total_Score 학습목표    학습방법            강의 학습 교재 유형  ... 취약분야 인지 여부  \
# 0               681.0   승진   온라인강의                  영상 교재  ...      알고 있음
# ...

# %%
## 고생 정말 많으셨습니다!!
## 실습시간이 남으신 분은 '중급'용 파일에 도전해보세요.
