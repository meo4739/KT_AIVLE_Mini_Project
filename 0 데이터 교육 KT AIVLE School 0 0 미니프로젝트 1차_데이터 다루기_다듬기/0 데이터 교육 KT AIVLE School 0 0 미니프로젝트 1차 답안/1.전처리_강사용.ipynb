# %% [markdown]
# # **토익 진단평가 데이터 다듬기**
# # 단계1 : 데이터 전처리
#  * 이번 시간에는 파이썬을 활용한 AI모델링에서 전처리에 대해 실습해보겠습니다.
#  * 전처리란 데이터 분석을 수행하기 전에 데이터를 적절한 형태로 가공하는 과정을 말합니다.
#  * 머신러닝과 AI모델링에서 70% 차지하는 부분이 바로 전처리 파트입니다.
#  * 굉장히 시간과 노력이 많이 투입되며, 어려운 부분일 수 있습니다.
#  * 데이터의 이상치나 결측치를 제거하거나, 변수를 수치형으로 변환하거나, 표준화나 정규화를 적용하는 등의 작업이 있습니다.
#  * 데이터가 깨끗이 정리되지 않으면 머신러닝/AI 성능을 장담할 수 없습니다.
#  * 데이터 전처리에 심혈을 기울여주시기 바라며, 이론보다 실습이 더 많은 시간과 노력이 투자되어야 합니다.

# %% [markdown]
# ## 0.미션 확인

# %% [markdown]
# * 개요
#     * 응시할 토익점수를 예측해주는 모델을 생성하기 위한 데이터를 전처리하려고 합니다.
#     * 이를 위해 주어진 데이터는 응시자별 3회차씩의 토익점수와 당시 학습방식 등의 정보 입니다.
#     * 관련 토익점수 및 학습정보 데이터를 분석하여 미니프로젝트 1차 이후에 예측 모델을 개발하여
#       토익 응시생들에게 도움이 되는 솔루션을 개발하려고 합니다.
# * 전처리 단계 목표
#     * 3회차(3행)의 데이터를 하나의 분석단위(1행)로 만들기 위해 응시자별 데이터를 집계합니다.
#     * 응시자는 하나의 ID로 구분됩니다.
#     * 응시회차는 seq로 구분됩니다. 모든 응시자가 1,2,3 의 회차 값을 갖고 있습니다.
# * 학습목차
#     0) 미션 내용 확인
#     1) 환경설정 : 라이브러리 불러오기 및 파일 읽어오기
#     2) 데이터프레임 탐색
#     3) 데이터 전처리 수행 (불필요 컬럼 삭제, Null 처리, 중복값 제거, 한 행으로 합치기 등)
#     4) 결과 저장하기

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# ### (1) 라이브러리 불러오기

# %% [markdown]
# * **세부 요구사항**
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드를 작성해주세요.
#     - 필요하다고 판단되는 라이브러리를 추가하겠습니다.
#     - Numpy패키지 : Numerical python의 줄임말, 벡터 및 행렬 연산에 있어서 편리한 기능, array 단위 연산 수행
#     - Pandas패키지 : 테이블을 수정하고 조작하는 다양한 기능 제공, 데이터 분석을 할 때 가장 많이 쓰이는 패키지

# %%
#[문제] pandas, numpy 라이브러리를 임포트하세요.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### (2) 데이터 불러오기
# * 읽어올 데이터 파일
#     * 학습 데이터 : data04.xls
#     * 엑셀 파일이므로 pd.read_excel 함수를 이용해서 불러 옵니다.
# * 다음과 같이 데이터를 불러와주세요.
#     * 주피터랩 실행
#         * 제공된 압축파일 '미프 1차_토익'을 다운받아 압축을 해제합니다.
#         * anaconda의 root directory(C:\Users\<ID>) 에 '미프 1차_토익' 폴더를 만들고, 복사합니다.
#         * '1.전처리_교육생용'과 '2.데이터_탐색_교육생용' 실습 파일을 열어주세요.

# %% [markdown]
# #### 1) 주피터랩 실행
# * '미프 1차_토익' 폴더에 필요한 파일들을 넣고, 본 파일을 열거나, 별도 경로를 지정해서 데이터를 읽어올 수 있습니다.

# %%
#[문제] '미프 1차_토익' 폴더에서 본 파일인 '1.전처리_교육생용'을 열어주세요.
##[해설] 현재 작업 중인 디렉토리를 기준으로 하는 파일을 불러와주시기 바랍니다. 
##[해설] 왼쪽에 보이는 현재 위치를 기준으로 경로를 표기하면 상대경로는 path = '../미프 1차_토익'

# %% [markdown]
# #### 2) 데이터 읽어오기
# * 데이터를 읽어오고 데이터 정보를 확인합니다.

# %%
#[문제] data04.xlsx 파일을 Pandas read_excel 함수를 이용하여 읽고 data변수에 저장하세요.
##[해설] 데이터를 읽어오는 함수는 pd.read_excel을 사용합니다. CSV 파일일 경우, pd.read_csv로 불러와주세요.

# %%
# 읽어들일 파일명 : data04.xlsx 
# Pandas read_excel 함수 활용
# 결과 : data 저장
data = pd.read_excel('data04.xlsx')
file = 'data04.xlsx'

# %%
#[문제] 읽어온 데이터프레임을 확인하고, 상위 10개 행만 보여주세요.
##[해설] 텍스트 파일이나 데이터의 처음 부분을 출력하는 head 함수를 사용하고 데이터를 확인합니다.

# %%
data.head(10)
# Out:
#    ID  Seq Gender  Birth_Year  LC_Score  RC_Score  Total Score  학습목표    학습방법  \
# 0   1    1      M        1973       181       173          354  자기계발     참고서
# 1   1    2      M        1973       227       213          440  자기계발  오프라인강의
# 2   1    3      M        1973       345       336          681    승진   온라인강의
# 3   2    1      F        1982       330       290          620  자기계발  오프라인강의
# 4   2    2      F        1982       354       339          693    승진   온라인강의
# 5   2    3      F        1982       380       368          748    승진   온라인강의
# 6   3    1      F        1995       367       309          676    취업   온라인강의
# 7   3    2      F        1995       396       365          761  자기계발   온라인강의
# 8   3    3      F        1995       416       382          798  자기계발     참고서
# 9   4    1      M        1987       470       285          755  자기계발   온라인강의
#
#          강의 학습 교재 유형      학습빈도  기출문제 공부 횟수 취약분야 인지 여부  토익 모의테스트 횟수 Student ID
# 0  일반적인 영어 텍스트 기반 교재     주3-4회         6.0   알고 있지 않음            6   student1
# 1        뉴스/이슈 기반 교재     주1-2회         3.0      알고 있음            5   student1
# 2              영상 교재     주5-6회         7.0      알고 있음           10   student1
# 3        뉴스/이슈 기반 교재  매일(주 7회)         8.0   알고 있지 않음           19   student2
# 4              영상 교재     주5-6회         2.0      알고 있음           15   student2
# 5        뉴스/이슈 기반 교재     주5-6회         4.0      알고 있음           14   student2
# 6              영상 교재  매일(주 7회)         9.0   알고 있지 않음            7   student3
# 7              영상 교재     주3-4회         7.0   알고 있지 않음            6   student3
# 8  일반적인 영어 텍스트 기반 교재     주1-2회         4.0      알고 있음            4   student3
# 9        뉴스/이슈 기반 교재     주1-2회         7.0   알고 있지 않음            4   student4

# %%
data.values
# Out:
# array([[1, 1, 'M', ..., '알고 있지 않음', 6, 'student1'],
#        [1, 2, 'M', ..., '알고 있음', 5, 'student1'],
#        [1, 3, 'M', ..., '알고 있음', 10, 'student1'],
#        ...,
#        [500, 1, 'M', ..., '알고 있지 않음', 2, 'student500'],
#        [500, 2, 'M', ..., '알고 있음', 16, 'student500'],
#        [500, 3, 'M', ..., '알고 있음', 15, 'student500']], dtype=object)

# %% [markdown]
# ### 2. 데이터프레임 탐색

# %% [markdown]
# * **세부 요구사항**
#     - data의 형태, 기초통계량, 정보 등을 확인합니다.
#     - 특히 .info() 를 통해서 각 변수별 데이터타입이 적절한지 확인합니다.
#     - 다양한 함수로 데이터를 탐색해주세요.

# %%
#[문제] 전체 데이터의 행,열 개수를 확인하기
##[해설] shape 함수는 데이터의 행, 열 개수를 확인할 때 사용됩니다.

# %%
data.shape
# Out:
# (1500, 15)

# %%
#[문제] 전체 데이터의 하위 5개 행 확인하기
##[해설] 데이터의 끝 부분을 출력하는 tail 함수를 사용해봅니다.

# %%
data.tail(5)
# Out:
#        ID  Seq Gender  Birth_Year  LC_Score  RC_Score  Total Score  학습목표  \
# 1495  499    2      F        1990       378       326          704    승진
# 1496  499    3      F        1990       422       370          792  자기계발
# 1497  500    1      M        1984       169       188          357  자기계발
# 1498  500    2      M        1984       172       190          362  자기계발
# 1499  500    3      M        1984       235       226          461    승진
#
#         학습방법            강의 학습 교재 유형      학습빈도  기출문제 공부 횟수 취약분야 인지 여부  \
# 1495   온라인강의            뉴스/이슈 기반 교재     주5-6회         6.0   알고 있지 않음
# 1496  오프라인강의  비즈니스 시뮬레이션(Role Play)     주3-4회         4.0      알고 있음
# 1497     참고서      일반적인 영어 텍스트 기반 교재     주3-4회         8.0   알고 있지 않음
# 1498     참고서            뉴스/이슈 기반 교재  매일(주 7회)        10.0      알고 있음
# 1499  오프라인강의  비즈니스 시뮬레이션(Role Play)     주5-6회         7.0      알고 있음
#
#       토익 모의테스트 횟수  Student ID
# 1495           12  student499
# 1496            7  student499
# 1497            2  student500
# 1498           16  student500
# 1499           15  student500

# %%
#[문제] 전체 데이터의 모든 변수 확인하기
##[해설] 데이터프레임의 열(컬럼)에 대한 정보를 가져올 때는 columns 함수를 사용합니다. 이때 열 이름은 리스트로 반환되어 열 이름들을 확인할 수 있습니다.

# %%
data.columns
# Out:
# Index(['ID', 'Seq', 'Gender', 'Birth_Year', 'LC_Score', 'RC_Score',
#        'Total Score', '학습목표', '학습방법', '강의 학습 교재 유형', '학습빈도', '기출문제 공부 횟수',
#        '취약분야 인지 여부', '토익 모의테스트 횟수', 'Student ID'],
#       dtype='object')

# %%
#[문제] 전체 데이터 정보 확인
##[해설] 데이터의 열 수나 열 이름, 데이터 타입(int 정수, float 소수점데이터, object 객체데이터), 메모리 사용량 등을 확인하는데 info 함수로 확인합니다.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           1500 non-null   int64
#  1   Seq          1500 non-null   int64
#  2   Gender       1500 non-null   object
#  3   Birth_Year   1500 non-null   int64
#  4   LC_Score     1500 non-null   int64
#  5   RC_Score     1500 non-null   int64
#  6   Total Score  1500 non-null   int64
#  7   학습목표         1500 non-null   object
#  8   학습방법         1500 non-null   object
#  9   강의 학습 교재 유형  1500 non-null   object
#  10  학습빈도         1500 non-null   object
#  11  기출문제 공부 횟수   1497 non-null   float64
#  12  취약분야 인지 여부   1500 non-null   object
#  13  토익 모의테스트 횟수  1500 non-null   int64
#  14  Student ID   1500 non-null   object
# dtypes: float64(1), int64(7), object(7)
# memory usage: 175.9+ KB

# %%
#[문제] 각 열별 Null 데이터 값의 개수를 확인해주세요.
##[해설] isnull 또는 isna 함수로 누락된 값 여부를 표시, 그 결과를 sum을 이용하여 열마다 결측치 개수를 합산
##[해설] isnull() 메소드 : 결측치는 True, 유효한 값은 False 반환

# %%
data.isnull()
# Out:
#          ID    Seq  Gender  Birth_Year  LC_Score  RC_Score  Total Score  \
# 0     False  False   False       False     False     False        False
# 1     False  False   False       False     False     False        False
# 2     False  False   False       False     False     False        False
# 3     False  False   False       False     False     False        False
# 4     False  False   False       False     False     False        False
# ...     ...    ...     ...         ...       ...       ...          ...
# 1495  False  False   False       False     False     False        False
# 1496  False  False   False       False     False     False        False
# 1497  False  False   False       False     False     False        False
# 1498  False  False   False       False     False     False        False
# 1499  False  False   False       False     False     False        False
#
#        학습목표   학습방법  강의 학습 교재 유형   학습빈도  기출문제 공부 횟수  취약분야 인지 여부  토익 모의테스트 횟수  \
# 0     False  False        False  False       False       False        False
# 1     False  False        False  False       False       False        False
# 2     False  False        False  False       False       False        False
# 3     False  False        False  False       False       False        False
# 4     False  False        False  False       False       False        False
# ...     ...    ...          ...    ...         ...         ...          ...
# 1495  False  False        False  False       False       False        False
# 1496  False  False        False  False       False       False        False
# 1497  False  False        False  False       False       False        False
# 1498  False  False        False  False       False       False        False
# 1499  False  False        False  False       False       False        False
#
#       Student ID
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 1495       False
# 1496       False
# 1497       False
# 1498       False
# 1499       False
#
# [1500 rows x 15 columns]

# %%
data.isnull().sum()
# Out:
# ID             0
# Seq            0
# Gender         0
# Birth_Year     0
# LC_Score       0
# RC_Score       0
# Total Score    0
# 학습목표           0
# 학습방법           0
# 강의 학습 교재 유형    0
# 학습빈도           0
# 기출문제 공부 횟수     3
# 취약분야 인지 여부     0
# 토익 모의테스트 횟수    0
# Student ID     0
# dtype: int64

# %%
#[추가문제] '기출문제 공부 횟수' 열에 있는 결측치가 있는 행을 제거해주세요.
##[해설] dropna() 메서드로 결측치가 있는 열이나 행을 제거할 수 있어야 합니다.
##[해설] subset 매개변수에 열을 지정하면 특정 열에 있는 결측치가 있는 행을 제거할 수 있음

# %%
#[문제] 데이터의 통계정보를 확인해주세요.
##[해설] describe 함수는 데이터의 분포, 최소값, 최대값 등 통계 정보를 한눈에 파악할 수 있도록 도와주는 유용한 함수입니다.
##[해설] 개수, 평균, 표준편차(std), 최소값, 각 열별 백분위수, 최대값을 보여줍니다.

# %%
data.describe()
# Out:
#                 ID          Seq   Birth_Year     LC_Score     RC_Score  \
# count  1500.000000  1500.000000  1500.000000  1500.000000  1500.000000
# mean    250.500000     2.000000  1992.906000   340.079333   340.164667
# std     144.385415     0.816769     8.218893    86.807523    87.143890
# min       1.000000     1.000000  1973.000000   105.000000    84.000000
# 25%     125.750000     1.000000  1986.750000   279.000000   280.000000
# 50%     250.500000     2.000000  1992.500000   335.000000   337.000000
# 75%     375.250000     3.000000  2000.000000   404.000000   406.000000
# max     500.000000     3.000000  2007.000000   495.000000   495.000000
#
#        Total Score   기출문제 공부 횟수  토익 모의테스트 횟수
# count  1500.000000  1497.000000  1500.000000
# mean    680.260667     5.286573     9.784000
# std     159.110652     2.797303     5.324181
# min     250.000000     1.000000     1.000000
# 25%     564.000000     3.000000     5.000000
# 50%     687.000000     5.000000     9.000000
# 75%     800.000000     8.000000    14.000000
# max     990.000000    10.000000    20.000000

# %% [markdown]
# ## 3.데이터 전처리 수행

# %% [markdown]
# *  **세부 요구사항**
#     * 여기부터는 스스로 실습해봅시다.
#     * ID를 기준으로 3회차(3행) 데이터를 1개의 분석단위(1행)으로 만들어야 합니다.
#         * (1) 개인정보 데이터와 각 회차별 학습정보 데이터 분리
#         * (2) 개인정보의 중복값 제거
#         * (3) 각 회차별 정보를 한 행으로 만들기
#         * (4) (2)와 (3)을 합치기 (merge, ID 기준)
#         * (5) 레이블 만들기 (2회차와 3회차 점수 차이)
#     * 전처리 결과를 다시 한번 정리해봅니다.

# %% [markdown]
# ### (1) 컬럼삭제 및 값변경, 개인정보와 각 회차별 학습정보 분리
#     * 컬럼선택 : data['ID'], data[['ID', 'Seq']] #2개 이상의 열을 선택할 경우 대괄호를 2개 입력
#     * drop() 메소드를 사용해 열삭제 (axis=0은 행삭제, axis=1은 열삭제)

# %%
#[문제] data의 컬럼별 데이터 타입을 출력하세요.
##[해설] info함수 : 데이터의 열수, 열이름, 데이터타입(int 정수, float 소수점, object 객체), 메모리 사용량 등을 확인

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           1500 non-null   int64
#  1   Seq          1500 non-null   int64
#  2   Gender       1500 non-null   object
#  3   Birth_Year   1500 non-null   int64
#  4   LC_Score     1500 non-null   int64
#  5   RC_Score     1500 non-null   int64
#  6   Total Score  1500 non-null   int64
#  7   학습목표         1500 non-null   object
#  8   학습방법         1500 non-null   object
#  9   강의 학습 교재 유형  1500 non-null   object
#  10  학습빈도         1500 non-null   object
#  11  기출문제 공부 횟수   1497 non-null   float64
#  12  취약분야 인지 여부   1500 non-null   object
#  13  토익 모의테스트 횟수  1500 non-null   int64
#  14  Student ID   1500 non-null   object
# dtypes: float64(1), int64(7), object(7)
# memory usage: 175.9+ KB

# %%
#[문제] data에서 'Student ID' 컬럼을 삭제하세요.
##[해설] 특정 컬럼을 삭제할 때는 drop 함수 사용, axis=1은 열을 의미하므로 drop함수에서 지정하면 열을 삭제하게 됩니다.
##[해설] inplace=True 매개변수는 원본 변경, 새로운 객체를 생성하지 않고 따로 저장하지 않아도 data에 직접 수정
##[해설] drop(columns=, index=, axis=)에서 columns : 삭제한 열 정보, index : 삭제할 행 정보, axis : 행,열 기준 정보
##[해설] 0 : 행기준 삭제, 1 : 열기준 삭제

# %%
# axis=1 옵션 사용, 컬럼단위 삭제(drop함수)
# inplace=True 옵션 사용, data 데이터프레임에 저장
# 2개 열을 삭제하고 싶으면 대괄호 안에 열 2개 삽입

data.drop('Student ID', axis=1, inplace=True)

# %%
#[문제] 14개컬럼에서 13개컬럼으로 줄어든 것을 확인해주세요.
##[해설] 열 수나 열 이름, 데이터 타입, 메모리 사용량 등을 확인하는데 info 함수로 확인합니다.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           1500 non-null   int64
#  1   Seq          1500 non-null   int64
#  2   Gender       1500 non-null   object
#  3   Birth_Year   1500 non-null   int64
#  4   LC_Score     1500 non-null   int64
#  5   RC_Score     1500 non-null   int64
#  6   Total Score  1500 non-null   int64
#  7   학습목표         1500 non-null   object
#  8   학습방법         1500 non-null   object
#  9   강의 학습 교재 유형  1500 non-null   object
#  10  학습빈도         1500 non-null   object
#  11  기출문제 공부 횟수   1497 non-null   float64
#  12  취약분야 인지 여부   1500 non-null   object
#  13  토익 모의테스트 횟수  1500 non-null   int64
# dtypes: float64(1), int64(7), object(6)
# memory usage: 164.2+ KB

# %%
#[문제] data 데이터프레임에서 '기출문제 공부 횟수' 컬럼의 Null 값을 '' --> '0'으로 변경하세요.
##[해설] fillna함수는 누락된 값을 다른 값으로 채우는 작업, '기출문제 공부횟수' 컬럼은 1497개의 non-null을 가지고 있음 
##[해설] data['기출문제 공부 횟수']의 누락값을 0으로 채우고, inplace=True를 설정하면 원본 데이터프레임을 변경
##[해설] fillna함수는 0과 같은 특정값으로 채우거나 평균값으로 채우는게 일반적임
##[해설] '기출문제 공부 횟수' 컬럼의 Null 값을 평균값으로 변경 : mean_공부횟수 = data['기출문제 공부 횟수'].mean() 
##[해설] 코드 : data['기출문제 공부 횟수'].fillna(mean_공부횟수, inplace=True)

# %%
# fillna 함수
# 대상컬럼 : '기출문제 공부 횟수'

data['기출문제 공부 횟수'].fillna(0, inplace=True)

# %%
#[문제] '기출문제 공부 횟수' 컬럼의 값 0으로 변경 확인
##[해설] isnull 함수로 null값의 열별 개수 확인. 누락된 값을 0으로 대체하는 것은 항상 옳은 선택은 아니지만 데이터 분석에서
##[해설] 누락된 값으로 인한 오류를 방지하거나 계산의 편의성을 높일 수 있습니다.

# %%
data.isnull().sum()
# Out:
# ID             0
# Seq            0
# Gender         0
# Birth_Year     0
# LC_Score       0
# RC_Score       0
# Total Score    0
# 학습목표           0
# 학습방법           0
# 강의 학습 교재 유형    0
# 학습빈도           0
# 기출문제 공부 횟수     0
# 취약분야 인지 여부     0
# 토익 모의테스트 횟수    0
# dtype: int64

# %%
#[문제] 개인정보 데이터와 토익시험 학습정보 데이터를 2개의 데이터 프레임인 df1, df2으로 각각 분리해주세요.
##[해설] 데이터프레임을 분리하는 이유는 필요한 조각으로 분할하여 각각 다른 분석이나 처리를 수행하기 위해서입니다.

# %%
# 개인정보 데이터는 features1, 토익시험 학습정보 데이터는 features2로 분리해주세요.
# df1(개인정보 데이터)에 포함될 features : 'ID', 'Gender', 'Birth_Year'
# df2(토익시험 학습정보 데이터)에 포함될 features : 'ID','Seq', 'LC_Score', 'RC_Score', 'Total Score', '학습목표', '학습방법', '강의 학습 교재 유형', '학습빈도', '기출문제 공부 횟수', '취약분야 인지 여부', '토익 모의테스트 횟수'

features1 = ['ID', 'Gender', 'Birth_Year']
features2 = ['ID','Seq', 'LC_Score', 'RC_Score', 'Total Score', '학습목표', '학습방법', '강의 학습 교재 유형', '학습빈도', '기출문제 공부 횟수', '취약분야 인지 여부', '토익 모의테스트 횟수']

# 개인정보 데이터
df1 = data[features1]

# 토익시험 학습정보 데이터
df2 = data[features2]

# %% [markdown]
# ### (2) 개인정보의 중복값 제거

# %%
#[문제] 개인정보 데이터 'df1'의 중복된 행을 제거해주세요.
##[해설] drop_duplicates 함수는 데이터프레임에서 중복된 행을 제거하는 작업 수행. 중복행은 모든 열의 값이 동일한 행을 의미합니다.
##[해설] 아래는 원본 데이터프레임에 바로 적용하므로 inplace=True로 설정한 것과 같은 의미입니다. 
##[해설] 중복값은 데이터의 정확성을 향상하기 위해 제거합니다.

# %%
# drop_duplicates 함수 활용
# 제거된 결과는 원본 데이터프레임 'df1'에 바로 적용
df1 = df1.drop_duplicates()

# %% [markdown]
# ### (3) 각 회차별 정보를 한 행으로 만들기
# * 우리는 3차시(Seq == 3)를 기준으로 1,2차시 정보를 집계하여 한 행으로 만들어 봅니다.
# * df.loc[조건]으로 조건을 지정해 조건에 만족하는 데이터만 조회하여 만들기

# %%
#[문제] 토익시험 학습정보 데이터 'df2'에서 각 ID별 차시(Seq)가 3인 행을 선택하여 새로운 데이터프레임 'temp'에 할당해 주세요.

##[해설] loc : 특정 행, 특정 행과 열, 그리고 조건에 따라 필터링된 행을 선택하는 함수, 행과 열에 조건도 줄 수 있음
##[해설] loc :명칭으로 선택, iloc :인덱스번호로 선택, # df.loc['index명', 'column명']=df.loc[행,열]
##[해설] loc함수는 행이나 열을 지정하여 해당 데이터에 접근. 'seq' 열이 3과 같은 행들만 필터링합니다.
##[해설] df2에서 seq열이 3인 행들만 선택되어 출력됩니다. temp를 출력하여 꼭 확인해주세요.
##[해설] 여러 조건에서 and 조건 : &, or 조건 : |, 같지 않다 : != 연산자 사용
##[해설] 차시가 1~2차시 조건을 만족하는 행 조회 : df2.loc[(df2['Seq'] >0) & (df2['Seq'] <3)]

# %%
# 3차시 데이터 : ['Seq'] == 3


temp = df2.loc[df2['Seq']==3]
temp
# Out:
#        ID  Seq  LC_Score  RC_Score  Total Score  학습목표    학습방법  \
# 2       1    3       345       336          681    승진   온라인강의
# 5       2    3       380       368          748    승진   온라인강의
# 8       3    3       416       382          798  자기계발     참고서
# 11      4    3       495       397          892    승진   온라인강의
# 14      5    3       398       437          835  자기계발   온라인강의
# ...   ...  ...       ...       ...          ...   ...     ...
# 1487  496    3       364       336          700  자기계발   온라인강의
# 1490  497    3       187       252          439    승진   온라인강의
# 1493  498    3       255       167          422  자기계발  오프라인강의
# 1496  499    3       422       370          792  자기계발  오프라인강의
# 1499  500    3       235       226          461    승진  오프라인강의
#
#                 강의 학습 교재 유형      학습빈도  기출문제 공부 횟수 취약분야 인지 여부  토익 모의테스트 횟수
# 2                     영상 교재     주5-6회         7.0      알고 있음           10
# 5               뉴스/이슈 기반 교재     주5-6회         4.0      알고 있음           14
# 8         일반적인 영어 텍스트 기반 교재     주1-2회         4.0      알고 있음            4
# 11              뉴스/이슈 기반 교재     주3-4회         9.0      알고 있음            8
# 14                    영상 교재     주3-4회         6.0      알고 있음            4
# ...                     ...       ...         ...        ...          ...
# 1487      일반적인 영어 텍스트 기반 교재  매일(주 7회)        10.0      알고 있음           13
# 1490  비즈니스 시뮬레이션(Role Play)  매일(주 7회)         9.0      알고 있음           17
# 1493      일반적인 영어 텍스트 기반 교재     주1-2회         0.0      알고 있음            4
# 1496  비즈니스 시뮬레이션(Role Play)     주3-4회         4.0      알고 있음            7
# 1499  비즈니스 시뮬레이션(Role Play)     주5-6회         7.0      알고 있음           15
#
# [500 rows x 12 columns]

# %%
#[문제] temp 데이터프레임의 열이름 중 'LC_Score', 'RC_Score', 'Total Score'를 각각 '3st_LC_Score', '3st_RC_Score', '3st_Total_Score'로 변경하고 확인해주세요.
##[해설] rename 함수 : 데이터프레임의 행 인덱스 또는 열 이름을 변경하는 데 사용  
##[해설] 이처럼 열에 더 의미있는 이름을 부여할 때 사용합니다. temp를 출력하여 반드시 확인해주세요.

# %%
# rename 함수 활용, temp에 저장
# {key: value} 형태의 딕셔너리를 생성할 때에는 중괄호를 사용합니다.
temp = temp.rename(columns = {'LC_Score':'3st_LC_Score','RC_Score':'3st_RC_Score','Total Score':'3st_Total_Score'})
temp
# Out:
#        ID  Seq  3st_LC_Score  3st_RC_Score  3st_Total_Score  학습목표    학습방법  \
# 2       1    3           345           336              681    승진   온라인강의
# 5       2    3           380           368              748    승진   온라인강의
# 8       3    3           416           382              798  자기계발     참고서
# 11      4    3           495           397              892    승진   온라인강의
# 14      5    3           398           437              835  자기계발   온라인강의
# ...   ...  ...           ...           ...              ...   ...     ...
# 1487  496    3           364           336              700  자기계발   온라인강의
# 1490  497    3           187           252              439    승진   온라인강의
# 1493  498    3           255           167              422  자기계발  오프라인강의
# 1496  499    3           422           370              792  자기계발  오프라인강의
# 1499  500    3           235           226              461    승진  오프라인강의
#
#                 강의 학습 교재 유형      학습빈도  기출문제 공부 횟수 취약분야 인지 여부  토익 모의테스트 횟수
# 2                     영상 교재     주5-6회         7.0      알고 있음           10
# 5               뉴스/이슈 기반 교재     주5-6회         4.0      알고 있음           14
# 8         일반적인 영어 텍스트 기반 교재     주1-2회         4.0      알고 있음            4
# 11              뉴스/이슈 기반 교재     주3-4회         9.0      알고 있음            8
# 14                    영상 교재     주3-4회         6.0      알고 있음            4
# ...                     ...       ...         ...        ...          ...
# 1487      일반적인 영어 텍스트 기반 교재  매일(주 7회)        10.0      알고 있음           13
# 1490  비즈니스 시뮬레이션(Role Play)  매일(주 7회)         9.0      알고 있음           17
# 1493      일반적인 영어 텍스트 기반 교재     주1-2회         0.0      알고 있음            4
# 1496  비즈니스 시뮬레이션(Role Play)     주3-4회         4.0      알고 있음            7
# 1499  비즈니스 시뮬레이션(Role Play)     주5-6회         7.0      알고 있음           15
#
# [500 rows x 12 columns]

# %%
#[문제] 토익시험 학습정보 데이터 'df2'의  각 ID별 차시(Seq)가 1인 행을 선택하여 새로운 데이터프레임 'temp1'에 할당해 주세요.
##[해설] loc함수는 행이나 열을 지정하여 해당 데이터에 접근할 수 있습니다. 'seq' 열이 1과 같은 행들만 필터링합니다.
##[해설] 결과적으로 df2에서 seq열이 1인 행들만 선택되어 출력됩니다. temp1를 출력하여 꼭 확인해주세요.

# %%
# 1차시 데이터 : ['Seq'] == 1
# loc 함수 활용 : 특정 행, 특정 행과 열, 그리고 조건에 따라 필터링된 행을 선택하는 함수

temp1 = df2.loc[df2['Seq']==1]
temp1
# Out:
#        ID  Seq  LC_Score  RC_Score  Total Score  학습목표    학습방법  \
# 0       1    1       181       173          354  자기계발     참고서
# 3       2    1       330       290          620  자기계발  오프라인강의
# 6       3    1       367       309          676    취업   온라인강의
# 9       4    1       470       285          755  자기계발   온라인강의
# 12      5    1       273       372          645    승진  오프라인강의
# ...   ...  ...       ...       ...          ...   ...     ...
# 1485  496    1       347       315          662  자기계발   온라인강의
# 1488  497    1       112       250          362  자기계발   온라인강의
# 1491  498    1       252       150          402  자기계발   온라인강의
# 1494  499    1       371       324          695  자기계발  오프라인강의
# 1497  500    1       169       188          357  자기계발     참고서
#
#                 강의 학습 교재 유형      학습빈도  기출문제 공부 횟수 취약분야 인지 여부  토익 모의테스트 횟수
# 0         일반적인 영어 텍스트 기반 교재     주3-4회         6.0   알고 있지 않음            6
# 3               뉴스/이슈 기반 교재  매일(주 7회)         8.0   알고 있지 않음           19
# 6                     영상 교재  매일(주 7회)         9.0   알고 있지 않음            7
# 9               뉴스/이슈 기반 교재     주1-2회         7.0   알고 있지 않음            4
# 12    비즈니스 시뮬레이션(Role Play)     주5-6회         3.0   알고 있지 않음           13
# ...                     ...       ...         ...        ...          ...
# 1485            뉴스/이슈 기반 교재     주1-2회         7.0   알고 있지 않음            1
# 1488                  영상 교재     주5-6회         4.0   알고 있지 않음           10
# 1491                  영상 교재     주3-4회         6.0   알고 있지 않음           15
# 1494  비즈니스 시뮬레이션(Role Play)     주1-2회         0.0   알고 있지 않음            5
# 1497      일반적인 영어 텍스트 기반 교재     주3-4회         8.0   알고 있지 않음            2
#
# [500 rows x 12 columns]

# %%
#[문제] 'temp1'에는 temp1['ID','LC_Score','RC_Score','Total Score'] 컬럼만 불러와 주세요.
##[해설] 특정 컬럼만 작성하여 temp1을 출력합니다.

# %%
temp1 = temp1[['ID','LC_Score','RC_Score','Total Score']]
temp1
# Out:
#        ID  LC_Score  RC_Score  Total Score
# 0       1       181       173          354
# 3       2       330       290          620
# 6       3       367       309          676
# 9       4       470       285          755
# 12      5       273       372          645
# ...   ...       ...       ...          ...
# 1485  496       347       315          662
# 1488  497       112       250          362
# 1491  498       252       150          402
# 1494  499       371       324          695
# 1497  500       169       188          357
#
# [500 rows x 4 columns]

# %%
#[문제] temp1 데이터프레임의 열이름 중 'LC_Score', 'RC_Score', 'Total Score'를 각각 '1st_LC_Score', '1st_RC_Score', '1st_Total_Score'로 변경해주세요.
##[해설] rename 함수는 열 이름을 변경하는데 사용됩니다. {key: value} 형태의 딕셔너리를 생성할 때에는 중괄호를 사용합니다. 이처럼 열에 더 의미있는 이름을 부여할 때 사용합니다.

# %%
# rename 함수 활용, temp1에 저장
temp1 = temp1.rename(columns = {'LC_Score':'1st_LC_Score','RC_Score':'1st_RC_Score','Total Score':'1st_Total_Score'})
temp1
# Out:
#        ID  1st_LC_Score  1st_RC_Score  1st_Total_Score
# 0       1           181           173              354
# 3       2           330           290              620
# 6       3           367           309              676
# 9       4           470           285              755
# 12      5           273           372              645
# ...   ...           ...           ...              ...
# 1485  496           347           315              662
# 1488  497           112           250              362
# 1491  498           252           150              402
# 1494  499           371           324              695
# 1497  500           169           188              357
#
# [500 rows x 4 columns]

# %%
#[문제] 토익시험 학습정보 데이터 'df2'에서 각 ID별 차시(Seq)가 2인 행을 선택하여 새로운 데이터프레임 'temp2'에 할당해 주세요.

# %%
# 2차시 데이터 : ['Seq'] == 2
# loc 함수 활용 : 특정 행, 특정 행과 열, 그리고 조건에 따라 필터링된 행을 선택
temp2 = df2.loc[df2['Seq']==2]
temp2
# Out:
#        ID  Seq  LC_Score  RC_Score  Total Score  학습목표    학습방법  \
# 1       1    2       227       213          440  자기계발  오프라인강의
# 4       2    2       354       339          693    승진   온라인강의
# 7       3    2       396       365          761  자기계발   온라인강의
# 10      4    2       495       341          836  자기계발   온라인강의
# 13      5    2       314       426          740  자기계발  오프라인강의
# ...   ...  ...       ...       ...          ...   ...     ...
# 1486  496    2       349       321          670  자기계발     참고서
# 1489  497    2       120       251          371  자기계발  오프라인강의
# 1492  498    2       254       158          412  자기계발   온라인강의
# 1495  499    2       378       326          704    승진   온라인강의
# 1498  500    2       172       190          362  자기계발     참고서
#
#                 강의 학습 교재 유형      학습빈도  기출문제 공부 횟수 취약분야 인지 여부  토익 모의테스트 횟수
# 1               뉴스/이슈 기반 교재     주1-2회         3.0      알고 있음            5
# 4                     영상 교재     주5-6회         2.0      알고 있음           15
# 7                     영상 교재     주3-4회         7.0   알고 있지 않음            6
# 10                    영상 교재     주1-2회         7.0   알고 있지 않음            7
# 13    비즈니스 시뮬레이션(Role Play)     주5-6회         8.0   알고 있지 않음           10
# ...                     ...       ...         ...        ...          ...
# 1486            뉴스/이슈 기반 교재     주3-4회         3.0   알고 있지 않음            4
# 1489                  영상 교재     주3-4회         5.0   알고 있지 않음            9
# 1492            뉴스/이슈 기반 교재     주5-6회         8.0   알고 있지 않음           18
# 1495            뉴스/이슈 기반 교재     주5-6회         6.0   알고 있지 않음           12
# 1498            뉴스/이슈 기반 교재  매일(주 7회)        10.0      알고 있음           16
#
# [500 rows x 12 columns]

# %%
#[문제] 'temp2'에는 temp2['ID','LC_Score','RC_Score','Total Score'] 컬럼만 불러와 주세요.

# %%
temp2 = temp2[['ID','LC_Score','RC_Score','Total Score']] #2개 이상의 열을 선택할 경우 대괄호를 2개 입력
temp2
# Out:
#        ID  LC_Score  RC_Score  Total Score
# 1       1       227       213          440
# 4       2       354       339          693
# 7       3       396       365          761
# 10      4       495       341          836
# 13      5       314       426          740
# ...   ...       ...       ...          ...
# 1486  496       349       321          670
# 1489  497       120       251          371
# 1492  498       254       158          412
# 1495  499       378       326          704
# 1498  500       172       190          362
#
# [500 rows x 4 columns]

# %%
#[문제] temp2 데이터프레임의 열이름 중 'LC_Score', 'RC_Score', 'Total Score'를 각각 '2st_LC_Score', '2st_RC_Score', '2st_Total_Score'로 변경해주세요.

# %%
# rename 함수 활용, temp2에 저장 및 확인
temp2 = temp2.rename(columns = {'LC_Score':'2st_LC_Score','RC_Score':'2st_RC_Score','Total Score':'2st_Total_Score'})
temp2
# Out:
#        ID  2st_LC_Score  2st_RC_Score  2st_Total_Score
# 1       1           227           213              440
# 4       2           354           339              693
# 7       3           396           365              761
# 10      4           495           341              836
# 13      5           314           426              740
# ...   ...           ...           ...              ...
# 1486  496           349           321              670
# 1489  497           120           251              371
# 1492  498           254           158              412
# 1495  499           378           326              704
# 1498  500           172           190              362
#
# [500 rows x 4 columns]

# %%
#[문제] 3회차 토익시험 정보가 모두 포함된 'temp' 데이터 + 1차시 토익시험점수 'temp1' 데이터을 합쳐서 'score_merged_data1'에 할당하세요.
##[해설] merge함수는 두 개 이상의 데이터프레임을 병합하는 작업 수행. 데이터프레임 내 공통 열인 'ID'열 기준 결합.
##[해설] how=outer는 데이터병합 방식의 합집합 형태. how=inner는 교집합, how=left는 왼쪽 데이터프레임의 모든 행을 포함

# %%
# 'temp'와 'temp1'을 'ID' 열 기준 조인, 'score_merged_data1'에 저장
# merge 함수 할용, how='outer'
score_merged_data1= pd.merge(temp, temp1, on='ID', how='outer')

# %%
#[문제] 'score_merged_data1'과 'temp2' 데이터를 합쳐서 'score_merged_data2'에 할당하세요.
##[해설] 위와 마찬가지로 pd.merge(행1, 행2, on='ID', how='outer')로 작성합니다.

# %%
# 'score_merged_data1'과 'temp2'을 'ID' 열을 기준으로 조인하여 'score_merged_data2'에 저장
# merge 함수 할용, how='outer'
score_merged_data2= pd.merge(score_merged_data1, temp2, on='ID', how='outer')

# %%
#[문제] score_merged_data2 데이터를 확인하세요.

# %%
score_merged_data2
# Out:
#       ID  Seq  3st_LC_Score  3st_RC_Score  3st_Total_Score  학습목표    학습방법  \
# 0      1    3           345           336              681    승진   온라인강의
# 1      2    3           380           368              748    승진   온라인강의
# 2      3    3           416           382              798  자기계발     참고서
# 3      4    3           495           397              892    승진   온라인강의
# 4      5    3           398           437              835  자기계발   온라인강의
# ..   ...  ...           ...           ...              ...   ...     ...
# 495  496    3           364           336              700  자기계발   온라인강의
# 496  497    3           187           252              439    승진   온라인강의
# 497  498    3           255           167              422  자기계발  오프라인강의
# 498  499    3           422           370              792  자기계발  오프라인강의
# 499  500    3           235           226              461    승진  오프라인강의
#
#                강의 학습 교재 유형      학습빈도  기출문제 공부 횟수 취약분야 인지 여부  토익 모의테스트 횟수  \
# 0                    영상 교재     주5-6회         7.0      알고 있음           10
# 1              뉴스/이슈 기반 교재     주5-6회         4.0      알고 있음           14
# 2        일반적인 영어 텍스트 기반 교재     주1-2회         4.0      알고 있음            4
# 3              뉴스/이슈 기반 교재     주3-4회         9.0      알고 있음            8
# 4                    영상 교재     주3-4회         6.0      알고 있음            4
# ..                     ...       ...         ...        ...          ...
# 495      일반적인 영어 텍스트 기반 교재  매일(주 7회)        10.0      알고 있음           13
# 496  비즈니스 시뮬레이션(Role Play)  매일(주 7회)         9.0      알고 있음           17
# 497      일반적인 영어 텍스트 기반 교재     주1-2회         0.0      알고 있음            4
# 498  비즈니스 시뮬레이션(Role Play)     주3-4회         4.0      알고 있음            7
# 499  비즈니스 시뮬레이션(Role Play)     주5-6회         7.0      알고 있음           15
#
#      1st_LC_Score  1st_RC_Score  1st_Total_Score  2st_LC_Score  2st_RC_Score  \
# 0             181           173              354           227           213
# 1             330           290              620           354           339
# 2             367           309              676           396           365
# 3             470           285              755           495           341
# 4             273           372              645           314           426
# ..            ...           ...              ...           ...           ...
# 495           347           315              662           349           321
# 496           112           250              362           120           251
# 497           252           150              402           254           158
# 498           371           324              695           378           326
# 499           169           188              357           172           190
#
#      2st_Total_Score
# 0                440
# 1                693
# 2                761
# 3                836
# 4                740
# ..               ...
# 495              670
# 496              371
# 497              412
# 498              704
# 499              362
#
# [500 rows x 18 columns]

# %% [markdown]
# ### (4) (2)개인정보 데이터와 (3)토익시험 학습정보 합치기

# %%
#[문제] 개인정보 데이터 'df1'과 토익시험 학습정보 'score_merged_data2'를 ID 기준으로 합치고 'baseline_data'에 할당하세요.
##[해설] df1과 score_merged_data2를 merge 함수를 사용해서 병합. 이로서 1,2,3회차 점수들을 ID기준의 개인정보 데이터와 합치게 되었습니다.

# %%
# merge 함수, 합쳐진 데이터는 'baseline_data'로 저장
baseline_data = pd.merge(df1, score_merged_data2, on='ID', how='outer')
baseline_data
# Out:
#       ID Gender  Birth_Year  Seq  3st_LC_Score  3st_RC_Score  3st_Total_Score  \
# 0      1      M        1973    3           345           336              681
# 1      2      F        1982    3           380           368              748
# 2      3      F        1995    3           416           382              798
# 3      4      M        1987    3           495           397              892
# 4      5      M        1994    3           398           437              835
# ..   ...    ...         ...  ...           ...           ...              ...
# 497  496      M        2006    3           364           336              700
# 498  497      F        1988    3           187           252              439
# 499  498      M        2006    3           255           167              422
# 500  499      F        1990    3           422           370              792
# 501  500      M        1984    3           235           226              461
#
#      학습목표    학습방법            강의 학습 교재 유형      학습빈도  기출문제 공부 횟수 취약분야 인지 여부  \
# 0      승진   온라인강의                  영상 교재     주5-6회         7.0      알고 있음
# 1      승진   온라인강의            뉴스/이슈 기반 교재     주5-6회         4.0      알고 있음
# 2    자기계발     참고서      일반적인 영어 텍스트 기반 교재     주1-2회         4.0      알고 있음
# 3      승진   온라인강의            뉴스/이슈 기반 교재     주3-4회         9.0      알고 있음
# 4    자기계발   온라인강의                  영상 교재     주3-4회         6.0      알고 있음
# ..    ...     ...                    ...       ...         ...        ...
# 497  자기계발   온라인강의      일반적인 영어 텍스트 기반 교재  매일(주 7회)        10.0      알고 있음
# 498    승진   온라인강의  비즈니스 시뮬레이션(Role Play)  매일(주 7회)         9.0      알고 있음
# 499  자기계발  오프라인강의      일반적인 영어 텍스트 기반 교재     주1-2회         0.0      알고 있음
# 500  자기계발  오프라인강의  비즈니스 시뮬레이션(Role Play)     주3-4회         4.0      알고 있음
# 501    승진  오프라인강의  비즈니스 시뮬레이션(Role Play)     주5-6회         7.0      알고 있음
#
#      토익 모의테스트 횟수  1st_LC_Score  1st_RC_Score  1st_Total_Score  2st_LC_Score  \
# 0             10           181           173              354           227
# 1             14           330           290              620           354
# 2              4           367           309              676           396
# 3              8           470           285              755           495
# 4              4           273           372              645           314
# ..           ...           ...           ...              ...           ...
# 497           13           347           315              662           349
# 498           17           112           250              362           120
# 499            4           252           150              402           254
# 500            7           371           324              695           378
# 501           15           169           188              357           172
#
#      2st_RC_Score  2st_Total_Score
# 0             213              440
# 1             339              693
# 2             365              761
# 3             341              836
# 4             426              740
# ..            ...              ...
# 497           321              670
# 498           251              371
# 499           158              412
# 500           326              704
# 501           190              362
#
# [502 rows x 20 columns]

# %% [markdown]
# ### (5) 레이블 만들기

# %% [markdown]
# * **세부 요구사항**
#     - 시험 2회차와 3회차의 Score 차이를 구하여 분석하고 싶습니다.
#     - 이를 계산해서 'Score_diff_total'이라는 변수로 추가해봅시다.
#     - 레이블을 만드는 것은 데이터를 의미있는 방식으로 구분하거나 식별하는 것을 말합니다.

# %%
#[문제] baseline_data 데이터프레임에서 2차시와 3차시의 시험점수 차이를 'Score_diff_total'이라는 변수로 'baseline_data'에 추가해주세요.
##[해설] baseline_data 데이터프레임의 3차시 Total_Score에서 2차시 Total_Score를 마이너스한 값을 'Score_diff_total' 열에 저장
##[해설] 이러한 변수로 시험 성적 변화를 추적하거나, 어떤 항목의 차이를 계산하는 등의 작업을 수행할 수 있습니다.

# %%
# baseline_data의 'Score_diff_total' 변수 = '3st_Total_Score'에서 '2st_Total_Score'를 마이너스한 값
baseline_data['Score_diff_total'] = baseline_data['3st_Total_Score'] - baseline_data['2st_Total_Score']

# %%
#[문제] baseline_data 확인해주세요.

# %%
baseline_data
# Out:
#       ID Gender  Birth_Year  Seq  3st_LC_Score  3st_RC_Score  3st_Total_Score  \
# 0      1      M        1973    3           345           336              681
# 1      2      F        1982    3           380           368              748
# 2      3      F        1995    3           416           382              798
# 3      4      M        1987    3           495           397              892
# 4      5      M        1994    3           398           437              835
# ..   ...    ...         ...  ...           ...           ...              ...
# 497  496      M        2006    3           364           336              700
# 498  497      F        1988    3           187           252              439
# 499  498      M        2006    3           255           167              422
# 500  499      F        1990    3           422           370              792
# 501  500      M        1984    3           235           226              461
#
#      학습목표    학습방법            강의 학습 교재 유형  ... 기출문제 공부 횟수  취약분야 인지 여부  \
# 0      승진   온라인강의                  영상 교재  ...        7.0       알고 있음
# 1      승진   온라인강의            뉴스/이슈 기반 교재  ...        4.0       알고 있음
# 2    자기계발     참고서      일반적인 영어 텍스트 기반 교재  ...        4.0       알고 있음
# 3      승진   온라인강의            뉴스/이슈 기반 교재  ...        9.0       알고 있음
# 4    자기계발   온라인강의                  영상 교재  ...        6.0       알고 있음
# ..    ...     ...                    ...  ...        ...         ...
# 497  자기계발   온라인강의      일반적인 영어 텍스트 기반 교재  ...       10.0       알고 있음
# 498    승진   온라인강의  비즈니스 시뮬레이션(Role Play)  ...        9.0       알고 있음
# 499  자기계발  오프라인강의      일반적인 영어 텍스트 기반 교재  ...        0.0       알고 있음
# 500  자기계발  오프라인강의  비즈니스 시뮬레이션(Role Play)  ...        4.0       알고 있음
# 501    승진  오프라인강의  비즈니스 시뮬레이션(Role Play)  ...        7.0       알고 있음
#
#     토익 모의테스트 횟수  1st_LC_Score  1st_RC_Score  1st_Total_Score  2st_LC_Score  \
# 0            10           181           173              354           227
# 1            14           330           290              620           354
# 2             4           367           309              676           396
# 3             8           470           285              755           495
# 4             4           273           372              645           314
# ..          ...           ...           ...              ...           ...
# 497          13           347           315              662           349
# 498          17           112           250              362           120
# 499           4           252           150              402           254
# 500           7           371           324              695           378
# 501          15           169           188              357           172
#
#      2st_RC_Score  2st_Total_Score  Score_diff_total
# 0             213              440               241
# 1             339              693                55
# 2             365              761                37
# 3             341              836                56
# 4             426              740                95
# ..            ...              ...               ...
# 497           321              670                30
# 498           251              371                68
# 499           158              412                10
# 500           326              704                88
# 501           190              362                99
#
# [502 rows x 21 columns]

# %% [markdown]
# ## 4.데이터셋 저장하기

# %% [markdown]
# * **세부 요구사항**
#     * to_csv를 이용하여 전처리된 데이터셋을 저장하세요.
#     * 저장할 파일의 확장자는 .csv 입니다.

# %%
#[문제] 전처리된 데이터프레임 'baseline_data'를 CSV 파일로 저장합니다.
##[해설] to_csv 함수를 사용, 데이터프레임의 내용을 CSV 파일로 저장. index=False할 경우 인덱스번호가 파일에 포함되지 않습니다. 
##[해설] 인덱스가 특별히 고유한 식별자가 아니기 때문에 인덱스를 제외하고 데이터를 저장하겠습니다.

# %%
# 파일명 : 'data04_baseline.csv'
# to_csv 함수 활용, index=False
baseline_data.to_csv('data04_baseline.csv', index=False)

# %%
#[문제] 제대로 저장이 잘 되었는지 'data04_baseline.csv' 파일을 불러와 확인해보세요.

# %%
pd.read_csv('data04_baseline.csv')
# Out:
#       ID Gender  Birth_Year  Seq  3st_LC_Score  3st_RC_Score  3st_Total_Score  \
# 0      1      M        1973    3           345           336              681
# 1      2      F        1982    3           380           368              748
# 2      3      F        1995    3           416           382              798
# 3      4      M        1987    3           495           397              892
# 4      5      M        1994    3           398           437              835
# ..   ...    ...         ...  ...           ...           ...              ...
# 497  496      M        2006    3           364           336              700
# 498  497      F        1988    3           187           252              439
# 499  498      M        2006    3           255           167              422
# 500  499      F        1990    3           422           370              792
# 501  500      M        1984    3           235           226              461
#
#      학습목표    학습방법            강의 학습 교재 유형  ... 기출문제 공부 횟수  취약분야 인지 여부  \
# 0      승진   온라인강의                  영상 교재  ...        7.0       알고 있음
# 1      승진   온라인강의            뉴스/이슈 기반 교재  ...        4.0       알고 있음
# 2    자기계발     참고서      일반적인 영어 텍스트 기반 교재  ...        4.0       알고 있음
# 3      승진   온라인강의            뉴스/이슈 기반 교재  ...        9.0       알고 있음
# 4    자기계발   온라인강의                  영상 교재  ...        6.0       알고 있음
# ..    ...     ...                    ...  ...        ...         ...
# 497  자기계발   온라인강의      일반적인 영어 텍스트 기반 교재  ...       10.0       알고 있음
# 498    승진   온라인강의  비즈니스 시뮬레이션(Role Play)  ...        9.0       알고 있음
# 499  자기계발  오프라인강의      일반적인 영어 텍스트 기반 교재  ...        0.0       알고 있음
# 500  자기계발  오프라인강의  비즈니스 시뮬레이션(Role Play)  ...        4.0       알고 있음
# 501    승진  오프라인강의  비즈니스 시뮬레이션(Role Play)  ...        7.0       알고 있음
#
#     토익 모의테스트 횟수  1st_LC_Score  1st_RC_Score  1st_Total_Score  2st_LC_Score  \
# 0            10           181           173              354           227
# 1            14           330           290              620           354
# 2             4           367           309              676           396
# 3             8           470           285              755           495
# 4             4           273           372              645           314
# ..          ...           ...           ...              ...           ...
# 497          13           347           315              662           349
# 498          17           112           250              362           120
# 499           4           252           150              402           254
# 500           7           371           324              695           378
# 501          15           169           188              357           172
#
#      2st_RC_Score  2st_Total_Score  Score_diff_total
# 0             213              440               241
# 1             339              693                55
# 2             365              761                37
# 3             341              836                56
# 4             426              740                95
# ..            ...              ...               ...
# 497           321              670                30
# 498           251              371                68
# 499           158              412                10
# 500           326              704                88
# 501           190              362                99
#
# [502 rows x 21 columns]

# %%
## 고생 정말 많으셨습니다!!
## 실습시간이 남으신 분은 '중급'용 파일에 도전해보세요.
