# %% [markdown]
# # **토익진단평가 데이터 다듬기2**
# # 단계2 : 데이터프레임 탐색

# %% [markdown]
# ## 0.미션

# %% [markdown]
# * 전처리 단계에서 생성한 데이터에 대한 데이터프레임 탐색을 해봅시다.
# * 개별 변수 및 개별 변수들 간의 관계에 대해 생각해보고, 분석해봅니다.

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# ### (1) 폰트 설치

# %%
# 아래 라이브러리를 수행해주세요.

# %%
# !pip install matplotlib
# !pip install --upgrade matplotlib

import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ### (2) 라이브러리 불러오기

# %% [markdown]
# * **세부 요구사항**
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드를 작성하였습니다.
#     - pandas, numpy, matplotlib 라이브러리를 실행해주세요.

# %%
#[문제] pandas 라이브러리를 임포트하세요.

# %%
import pandas as pd

# %%
#[문제] numpy 라이브러리를 임포트하세요.

# %%
import numpy as np

# %%
#[문제] matplotlib 라이브러리를 임포트하세요.

# %%
import matplotlib.pyplot as plt

# %%
#차트에 한글폰트 설정을 위해 아래 라이브러리를 실행해주세요.

# %%
plt.rc('font', family='Malgun Gothic')

# %% [markdown]
# ### (3) 데이터 불러오기
# * 1.데이터 전처리 단계에서 앞 시간에 생성한 데이터를 로딩합니다.
#     * data04_baseline.csv
# * 다음과 같이 데이터를 저장하여 불러와주세요.
#     * 주피터랩 수행
#         * 제공된 압축파일 '미프 1차_토익'을 다운받아 압축을 푼다.
#         * anaconda의 root directory(보통 C:\Users\<ID> 에 '미프 1차_토익' 폴더를 만들고, 복사해 넣습니다.
#         * '2.데이터_탐색_교육생용' 실습파일을 열어주세요.

# %% [markdown]
# #### 1) 주피터랩 수행

# %%
# '미프 1차_토익' 폴더에 필요한 파일들을 넣고, 본 파일을 열고 데이터를 읽어옵니다.

# %%
#[문제] '미프 1차_토익' 폴더에서 본 파일 '2.데이터_탐색_교육생용' 실습파일을 열어주세요.

# %% [markdown]
# #### 2) 저장된 데이터 읽어오기
# * [1.전처리] 단계에서 저장된 .csv 파일인 'data04_baseline.csv' 파일을 불러옵니다.
# * 불러 온 후에는 shape를 확인해 봅시다.

# %%
#[문제] data04_baseline.csv 파일을 pd.read_csv 함수를 이용하여 읽고 data변수에 할당하세요.

# %%
# 읽어들일 파일명 : data04_baseline.csv
# Pandas read_csv 함수 활용
# 결과 : data 저장

# %%
data = pd.read_csv('data04_baseline.csv')

# %%
#[문제] 읽어온 데이터프레임 data 확인해주세요.

# %%
data.head()
# Out:
#    ID Gender  Birth_Year  Seq  3st_LC_Score  RC_Score_x  3st_Total_Score  \
# 0   1      M        1973    3           345         336              681
# 1   2      F        1982    3           380         368              748
# 2   3      F        1995    3           416         382              798
# 3   4      M        1987    3           495         397              892
# 4   5      M        1994    3           398         437              835
#
#    학습목표   학습방법        강의 학습 교재 유형  ... 기출문제 공부 횟수  취약분야 인지 여부 토익 모의테스트 횟수  \
# 0    승진  온라인강의              영상 교재  ...        7.0       알고 있음          10
# 1    승진  온라인강의        뉴스/이슈 기반 교재  ...        4.0       알고 있음          14
# 2  자기계발    참고서  일반적인 영어 텍스트 기반 교재  ...        4.0       알고 있음           4
# 3    승진  온라인강의        뉴스/이슈 기반 교재  ...        9.0       알고 있음           8
# 4  자기계발  온라인강의              영상 교재  ...        6.0       알고 있음           4
#
#    1st_LC_Score  RC_Score_y  1st_Total_Score  2st_LC_Score  RC_Score  \
# 0           181         173              354           227       213
# 1           330         290              620           354       339
# 2           367         309              676           396       365
# 3           470         285              755           495       341
# 4           273         372              645           314       426
#
#    2st_Total_Score  Score_diff_total
# 0              440               241
# 1              693                55
# 2              761                37
# 3              836                56
# 4              740                95
#
# [5 rows x 21 columns]

# %%
#[문제] data 데이터프레임의 열과 행을 확인해주세요.

# %%
data.shape
# Out:
# (502, 21)

# %%
#[문제] data 데이터프레임의 자료구조(Row, Column, Not-null, type)을 파악하세요.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                502 non-null    int64
#  1   Gender            502 non-null    object
#  2   Birth_Year        502 non-null    int64
#  3   Seq               502 non-null    int64
#  4   3st_LC_Score      502 non-null    int64
#  5   RC_Score_x        502 non-null    int64
#  6   3st_Total_Score   502 non-null    int64
#  7   학습목표              502 non-null    object
#  8   학습방법              502 non-null    object
#  9   강의 학습 교재 유형       502 non-null    object
#  10  학습빈도              502 non-null    object
#  11  기출문제 공부 횟수        502 non-null    float64
#  12  취약분야 인지 여부        502 non-null    object
#  13  토익 모의테스트 횟수       502 non-null    int64
#  14  1st_LC_Score      502 non-null    int64
#  15  RC_Score_y        502 non-null    int64
#  16  1st_Total_Score   502 non-null    int64
#  17  2st_LC_Score      502 non-null    int64
#  18  RC_Score          502 non-null    int64
#  19  2st_Total_Score   502 non-null    int64
#  20  Score_diff_total  502 non-null    int64
# dtypes: float64(1), int64(14), object(6)
# memory usage: 82.5+ KB

# %%
#[문제] 인덱스를 확인해보세요.

# %%
data.index
# Out:
# RangeIndex(start=0, stop=502, step=1)

# %%
#[문제] 컬럼명을 확인해보세요.

# %%
data.columns
# Out:
# Index(['ID', 'Gender', 'Birth_Year', 'Seq', '3st_LC_Score', 'RC_Score_x',
#        '3st_Total_Score', '학습목표', '학습방법', '강의 학습 교재 유형', '학습빈도', '기출문제 공부 횟수',
#        '취약분야 인지 여부', '토익 모의테스트 횟수', '1st_LC_Score', 'RC_Score_y',
#        '1st_Total_Score', '2st_LC_Score', 'RC_Score', '2st_Total_Score',
#        'Score_diff_total'],
#       dtype='object')

# %%
#[문제] 상단 5행을 확인해보세요

# %%
data.head(5)
# Out:
#    ID Gender  Birth_Year  Seq  3st_LC_Score  RC_Score_x  3st_Total_Score  \
# 0   1      M        1973    3           345         336              681
# 1   2      F        1982    3           380         368              748
# 2   3      F        1995    3           416         382              798
# 3   4      M        1987    3           495         397              892
# 4   5      M        1994    3           398         437              835
#
#    학습목표   학습방법        강의 학습 교재 유형  ... 기출문제 공부 횟수  취약분야 인지 여부 토익 모의테스트 횟수  \
# 0    승진  온라인강의              영상 교재  ...        7.0       알고 있음          10
# 1    승진  온라인강의        뉴스/이슈 기반 교재  ...        4.0       알고 있음          14
# 2  자기계발    참고서  일반적인 영어 텍스트 기반 교재  ...        4.0       알고 있음           4
# 3    승진  온라인강의        뉴스/이슈 기반 교재  ...        9.0       알고 있음           8
# 4  자기계발  온라인강의              영상 교재  ...        6.0       알고 있음           4
#
#    1st_LC_Score  RC_Score_y  1st_Total_Score  2st_LC_Score  RC_Score  \
# 0           181         173              354           227       213
# 1           330         290              620           354       339
# 2           367         309              676           396       365
# 3           470         285              755           495       341
# 4           273         372              645           314       426
#
#    2st_Total_Score  Score_diff_total
# 0              440               241
# 1              693                55
# 2              761                37
# 3              836                56
# 4              740                95
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 2.데이터프레임 탐색 : 개별 변수 분석하기

# %% [markdown]
# * **세부 요구사항**
#     * 기본 분석
#         * 기초 통계량, NaN 값 확인 등 기본 분석을 수행합니다.
#     * 주요 변수들의 분포를 살펴보기
#         * 숫자형 변수 : 기초통계량 조회 (평균, 중앙값, 표준편차 등)
#         * 범주형 변수 : 특정한 카테고리나 범주로 구성된 변수인 범주별 빈도수, 바 플롯 (예시 : 성별, 혈액형, 지역 등 그룹화할 수 있는 변수)
#         * 시각화나 통계분석에서 범주형 변수의 그룹 간의 차이나 관계를 분석할 때 중요한 역할을 합니다.

# %% [markdown]
# ### (1) 기본 분석

# %% [markdown]
# * **세부 요구사항**
#     - 데이터프레임 전체에 대한 기초통계량을 구합니다.
#     - NaN을 확인해봅니다.
#       * NaN이 존재한다면 Numpy 모듈에서 isna() 함수를 통해 판별하고 적절하게 조치해줍니다.

# %%
#[문제] 'data'의 각 열별 누락된 값(Nan, none) 개수를 확인해보세요.

# %%
#isna() 함수 활용
data.isna().sum()
# Out:
# ID                  0
# Gender              0
# Birth_Year          0
# Seq                 0
# 3st_LC_Score        0
# RC_Score_x          0
# 3st_Total_Score     0
# 학습목표                0
# 학습방법                0
# 강의 학습 교재 유형         0
# 학습빈도                0
# 기출문제 공부 횟수          0
# 취약분야 인지 여부          0
# 토익 모의테스트 횟수         0
# 1st_LC_Score        0
# RC_Score_y          0
# 1st_Total_Score     0
# 2st_LC_Score        0
# RC_Score            0
# 2st_Total_Score     0
# Score_diff_total    0
# dtype: int64

# %%
#[문제] 'data'의 각 열 통계량을 요약하여 출력하세요.

# %%
# describe 함수 활용
data.describe()
# Out:
#                ID   Birth_Year    Seq  3st_LC_Score  RC_Score_x  \
# count  502.000000   502.000000  502.0    502.000000  502.000000
# mean   250.587649  1992.948207    3.0    368.023904  369.318725
# std    144.199862     8.236603    0.0     82.052339   81.659228
# min      1.000000  1973.000000    3.0    141.000000  135.000000
# 25%    126.250000  1987.000000    3.0    295.000000  295.000000
# 50%    251.500000  1993.000000    3.0    372.000000  375.000000
# 75%    374.750000  2000.000000    3.0    434.000000  437.000000
# max    500.000000  2007.000000    3.0    495.000000  495.000000
#
#        3st_Total_Score  기출문제 공부 횟수  토익 모의테스트 횟수  1st_LC_Score  RC_Score_y  \
# count       502.000000  502.000000   502.000000    502.000000  502.000000
# mean        737.382470    5.087649     9.452191    313.697211  312.798805
# std         155.752174    2.790826     4.952137     85.483105   86.522443
# min         280.000000    0.000000     1.000000    105.000000   84.000000
# 25%         591.250000    3.000000     5.000000    259.250000  250.000000
# 50%         760.000000    5.000000     8.000000    308.000000  311.500000
# 75%         860.000000    7.000000    13.000000    369.000000  377.750000
# max         990.000000   10.000000    20.000000    495.000000  491.000000
#
#        1st_Total_Score  2st_LC_Score    RC_Score  2st_Total_Score  \
# count       502.000000    502.000000  502.000000       502.000000
# mean        626.496016    337.868526  338.045817       675.924303
# std         148.318758     84.141542   83.817809       152.986694
# min         250.000000    120.000000  129.000000       260.000000
# 25%         519.000000    279.000000  280.500000       558.750000
# 50%         641.000000    332.500000  335.000000       690.500000
# 75%         734.750000    395.000000  400.000000       790.000000
# max         970.000000    495.000000  495.000000       990.000000
#
#        Score_diff_total
# count        502.000000
# mean          61.458167
# std           39.684902
# min            0.000000
# 25%           30.000000
# 50%           63.000000
# 75%           83.000000
# max          281.000000

# %%
#[문제] 위에서 출력한 통계량 데이터프레임의 행과 열을 서로 바꾸어 출력하세요.

# %%
#'T'는 데이터프레임의 전치(Transpose)를 의미함
# descibe 함수 활용
data.T
# Out:
#                     0            1                  2            3      4    \
# ID                    1            2                  3            4      5
# Gender                M            F                  F            M      M
# Birth_Year         1973         1982               1995         1987   1994
# Seq                   3            3                  3            3      3
# 3st_LC_Score        345          380                416          495    398
# RC_Score_x          336          368                382          397    437
# 3st_Total_Score     681          748                798          892    835
# 학습목표                 승진           승진               자기계발           승진   자기계발
# 학습방법              온라인강의        온라인강의                참고서        온라인강의  온라인강의
# 강의 학습 교재 유형       영상 교재  뉴스/이슈 기반 교재  일반적인 영어 텍스트 기반 교재  뉴스/이슈 기반 교재  영상 교재
# 학습빈도              주5-6회        주5-6회              주1-2회        주3-4회  주3-4회
# 기출문제 공부 횟수          7.0          4.0                4.0          9.0    6.0
# 취약분야 인지 여부        알고 있음        알고 있음              알고 있음        알고 있음  알고 있음
# 토익 모의테스트 횟수          10           14                  4            8      4
# 1st_LC_Score        181          330                367          470    273
# RC_Score_y          173          290                309          285    372
# 1st_Total_Score     354          620                676          755    645
# 2st_LC_Score        227          354                396          495    314
# RC_Score            213          339                365          341    426
# 2st_Total_Score     440          693                761          836    740
# Score_diff_total    241           55                 37           56     95
#
#                     5                      6                      7    \
# ID                    6                      7                      8
# Gender                F                      F                      M
# Birth_Year         1997                   1990                   1973
# Seq                   3                      3                      3
# 3st_LC_Score        445                    495                    145
# RC_Score_x          352                    382                    135
# 3st_Total_Score     797                    877                    280
# 학습목표                 취업                   자기계발                   자기계발
# 학습방법              온라인강의                 오프라인강의                 오프라인강의
# 강의 학습 교재 유형       영상 교재  비즈니스 시뮬레이션(Role Play)  비즈니스 시뮬레이션(Role Play)
# 학습빈도              주5-6회                  주1-2회                  주3-4회
# 기출문제 공부 횟수          9.0                    4.0                    7.0
# 취약분야 인지 여부        알고 있음                  알고 있음               알고 있지 않음
# 토익 모의테스트 횟수           7                      4                      7
# 1st_LC_Score        360                    487                    132
# RC_Score_y          256                    337                    129
# 1st_Total_Score     616                    824                    261
# 2st_LC_Score        372                    495                    133
# RC_Score            269                    341                    130
# 2st_Total_Score     641                    836                    263
# Score_diff_total    156                     41                     17
#
#                           8      9    ...                492  \
# ID                          9     10  ...                491
# Gender                      M      F  ...                  F
# Birth_Year               1994   1984  ...               1985
# Seq                         3      3  ...                  3
# 3st_LC_Score              354    423  ...                287
# RC_Score_x                457    346  ...                330
# 3st_Total_Score           811    769  ...                617
# 학습목표                       승진     승진  ...                 승진
# 학습방법                    온라인강의  온라인강의  ...                참고서
# 강의 학습 교재 유형       뉴스/이슈 기반 교재  영상 교재  ...  일반적인 영어 텍스트 기반 교재
# 학습빈도                    주5-6회  주5-6회  ...           매일(주 7회)
# 기출문제 공부 횟수                8.0    8.0  ...                9.0
# 취약분야 인지 여부              알고 있음  알고 있음  ...              알고 있음
# 토익 모의테스트 횟수                10      8  ...                 17
# 1st_LC_Score              256    358  ...                269
# RC_Score_y                369    279  ...                331
# 1st_Total_Score           625    637  ...                600
# 2st_LC_Score              322    382  ...                271
# RC_Score                  425    305  ...                338
# 2st_Total_Score           747    687  ...                609
# Score_diff_total           64     82  ...                  8
#
#                                     493          494          495    496  \
# ID                                  492          493          494    495
# Gender                                M            F            M      F
# Birth_Year                         1980         2002         1996   2007
# Seq                                   3            3            3      3
# 3st_LC_Score                        301          420          301    267
# RC_Score_x                          321          427          310    275
# 3st_Total_Score                     622          847          611    542
# 학습목표                               자기계발         자기계발           승진   자기계발
# 학습방법                             오프라인강의          참고서          참고서  온라인강의
# 강의 학습 교재 유형       비즈니스 시뮬레이션(Role Play)  뉴스/이슈 기반 교재  뉴스/이슈 기반 교재  영상 교재
# 학습빈도                           매일(주 7회)     매일(주 7회)        주3-4회  주1-2회
# 기출문제 공부 횟수                         10.0          8.0          3.0    0.0
# 취약분야 인지 여부                        알고 있음        알고 있음        알고 있음  알고 있음
# 토익 모의테스트 횟수                          16           19            6      5
# 1st_LC_Score                        204          378          276    221
# RC_Score_y                          201          388          251    229
# 1st_Total_Score                     405          766          527    450
# 2st_LC_Score                        241          383          299    236
# RC_Score                            238          390          301    244
# 2st_Total_Score                     479          773          600    480
# Score_diff_total                    143           74           11     62
#
#                                 497                    498                499  \
# ID                              496                    497                498
# Gender                            M                      F                  M
# Birth_Year                     2006                   1988               2006
# Seq                               3                      3                  3
# 3st_LC_Score                    364                    187                255
# RC_Score_x                      336                    252                167
# 3st_Total_Score                 700                    439                422
# 학습목표                           자기계발                     승진               자기계발
# 학습방법                          온라인강의                  온라인강의             오프라인강의
# 강의 학습 교재 유형       일반적인 영어 텍스트 기반 교재  비즈니스 시뮬레이션(Role Play)  일반적인 영어 텍스트 기반 교재
# 학습빈도                       매일(주 7회)               매일(주 7회)              주1-2회
# 기출문제 공부 횟수                     10.0                    9.0                0.0
# 취약분야 인지 여부                    알고 있음                  알고 있음              알고 있음
# 토익 모의테스트 횟수                      13                     17                  4
# 1st_LC_Score                    347                    112                252
# RC_Score_y                      315                    250                150
# 1st_Total_Score                 662                    362                402
# 2st_LC_Score                    349                    120                254
# RC_Score                        321                    251                158
# 2st_Total_Score                 670                    371                412
# Score_diff_total                 30                     68                 10
#
#                                     500                    501
# ID                                  499                    500
# Gender                                F                      M
# Birth_Year                         1990                   1984
# Seq                                   3                      3
# 3st_LC_Score                        422                    235
# RC_Score_x                          370                    226
# 3st_Total_Score                     792                    461
# 학습목표                               자기계발                     승진
# 학습방법                             오프라인강의                 오프라인강의
# 강의 학습 교재 유형       비즈니스 시뮬레이션(Role Play)  비즈니스 시뮬레이션(Role Play)
# 학습빈도                              주3-4회                  주5-6회
# 기출문제 공부 횟수                          4.0                    7.0
# 취약분야 인지 여부                        알고 있음                  알고 있음
# 토익 모의테스트 횟수                           7                     15
# 1st_LC_Score                        371                    169
# RC_Score_y                          324                    188
# 1st_Total_Score                     695                    357
# 2st_LC_Score                        378                    172
# RC_Score                            326                    190
# 2st_Total_Score                     704                    362
# Score_diff_total                     88                     99
#
# [21 rows x 502 columns]

# %%
#[문제] Gender 컬럼의 값 별 개수를 확인해주세요. (Gender M : 남자, F : 여자)

# %%
# value_counts 함수 활용
data['Gender'].value_counts()
# Out:
# M    251
# F    251
# Name: Gender, dtype: int64

# %%
#[문제] 'Gender' 컬럼의 ['M', 'F'] --> [1,2]로 변경해해보세요.

# %%
# replace 함수 활용
data['Gender'] = data['Gender'].replace({'M':1, 'F':2 } )

# %%
#[문제] Gender 컬럼의 값 별 개수를 다시 확인해주세요.

# %%
data['Gender'].value_counts()
# Out:
# 1    251
# 2    251
# Name: Gender, dtype: int64

# %%
#[문제] 'Gender' 컬럼 타입을 object에서 int로 변경해보세요.

# %%
#astype 함수 활용
data = data.astype({'Gender':'int'})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                502 non-null    int64
#  1   Gender            502 non-null    int32
#  2   Birth_Year        502 non-null    int64
#  3   Seq               502 non-null    int64
#  4   3st_LC_Score      502 non-null    int64
#  5   RC_Score_x        502 non-null    int64
#  6   3st_Total_Score   502 non-null    int64
#  7   학습목표              502 non-null    object
#  8   학습방법              502 non-null    object
#  9   강의 학습 교재 유형       502 non-null    object
#  10  학습빈도              502 non-null    object
#  11  기출문제 공부 횟수        502 non-null    float64
#  12  취약분야 인지 여부        502 non-null    object
#  13  토익 모의테스트 횟수       502 non-null    int64
#  14  1st_LC_Score      502 non-null    int64
#  15  RC_Score_y        502 non-null    int64
#  16  1st_Total_Score   502 non-null    int64
#  17  2st_LC_Score      502 non-null    int64
#  18  RC_Score          502 non-null    int64
#  19  2st_Total_Score   502 non-null    int64
#  20  Score_diff_total  502 non-null    int64
# dtypes: float64(1), int32(1), int64(14), object(5)
# memory usage: 80.5+ KB

# %%
#[문제] data 데이터 프레임에서 Null 데이터가 있는지 확인해주세요.

# %%
data.isnull().sum()
# Out:
# ID                  0
# Gender              0
# Birth_Year          0
# Seq                 0
# 3st_LC_Score        0
# RC_Score_x          0
# 3st_Total_Score     0
# 학습목표                0
# 학습방법                0
# 강의 학습 교재 유형         0
# 학습빈도                0
# 기출문제 공부 횟수          0
# 취약분야 인지 여부          0
# 토익 모의테스트 횟수         0
# 1st_LC_Score        0
# RC_Score_y          0
# 1st_Total_Score     0
# 2st_LC_Score        0
# RC_Score            0
# 2st_Total_Score     0
# Score_diff_total    0
# dtype: int64

# %% [markdown]
# ### (2) 주요 변수의 분포를 살펴보기

# %% [markdown]
# * **세부 요구사항**
#     - 주요 변수들의 분포를 살펴보자.
#         * 대상 : 최종 차수 점수 변화, 생년월일, 학습목표, 학습방법, 강의 학습 교재 유형
#         * 도구 : 기초통계량, bar차트를 통한 데이터 분포 파악
#     - 전체 현황과 각 변수별 현황을 비교해보고 결과를 저장하자.

# %% [markdown]
# #### 1) 열 데이터 탐색 및 시각화 : 최종 차수 점수 변화(Score_diff_total)

# %%
#[문제] 변수 Sdt에 문자열 'Score_diff_total'을 할당 하세요.

# %%
Std = data['Score_diff_total']
Std
# Out:
# 0      241
# 1       55
# 2       37
# 3       56
# 4       95
#       ...
# 497     30
# 498     68
# 499     10
# 500     88
# 501     99
# Name: Score_diff_total, Length: 502, dtype: int64

# %%
#[문제] 'data' 데이터프레임의 'Score_diff_total'열에 대한 기술 통계 정보를 데이터 프레임의 형태로 출력해주세요.

# %%
# discribe() 함수 활용
data['Score_diff_total'].describe()
# Out:
# count    502.000000
# mean      61.458167
# std       39.684902
# min        0.000000
# 25%       30.000000
# 50%       63.000000
# 75%       83.000000
# max      281.000000
# Name: Score_diff_total, dtype: float64

# %%
#[문제] 위에서 추출한 데이터의 'Score_diff_total'에 대해 행과 열을 변환하여 기술 통계 정보를 출력해주세요.

# %%
# describe().T 함수 활용
# data['Score_diff_total'].describe().T  
# 시리즈 데이터라 행과 열을 변환하여 출력하기 전에 데이터 프레임으로 만듦
data['Score_diff_total'].to_frame().describe().T
# Out:
#                   count       mean        std  min   25%   50%   75%    max
# Score_diff_total  502.0  61.458167  39.684902  0.0  30.0  63.0  83.0  281.0

# %% [markdown]
# #### 2) 열 추가 : Bitrh_Year
# * 출생연도로 부터 나이 변수를 추출해 봅시다.

# %%
#[문제] 변수 BY에 문자열 'Birth_Year'을 할당하세요.

# %%
BY = data.loc[:,'Birth_Year']
BY
# Out:
# 0      1973
# 1      1982
# 2      1995
# 3      1987
# 4      1994
#        ...
# 497    2006
# 498    1988
# 499    2006
# 500    1990
# 501    1984
# Name: Birth_Year, Length: 502, dtype: int64

# %%
#[문제] 'data' 데이터프레임의 'Birth_Year'열에 대한 기술 통계 정보를 출력해주세요.
#'Birth_Year'에 대해 행과 열을 변환하여 기술 통계 정보를 출력해주세요.

# %%
# describe().T 함수 활용
BY.to_frame().describe().T
# Out:
#             count         mean       std     min     25%     50%     75%  \
# Birth_Year  502.0  1992.948207  8.236603  1973.0  1987.0  1993.0  2000.0
#
#                max
# Birth_Year  2007.0

# %%
#[문제] 'data' 데이터프레임의 'Birth_Year' 컬럼의 연도별 개수를 Bar 차트로 그리세요.

# %%
# DataFrame value_counts()와 plot() 함수 활용
# 대상 컬럼 : 'Birth_Year'
# plot 함수의 인자 : kind='bar'

data['Birth_Year'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# #### 3) 고유값 확인 : 컬럼 출력

# %%
#[문제] data 데이터프레임에서 object 컬럼에 대해서만 추출해서 보여주세요.

# %%
# select_dtypes() 함수 활용
data.select_dtypes(include = 'object')
# Out:
#      학습목표    학습방법            강의 학습 교재 유형      학습빈도 취약분야 인지 여부
# 0      승진   온라인강의                  영상 교재     주5-6회      알고 있음
# 1      승진   온라인강의            뉴스/이슈 기반 교재     주5-6회      알고 있음
# 2    자기계발     참고서      일반적인 영어 텍스트 기반 교재     주1-2회      알고 있음
# 3      승진   온라인강의            뉴스/이슈 기반 교재     주3-4회      알고 있음
# 4    자기계발   온라인강의                  영상 교재     주3-4회      알고 있음
# ..    ...     ...                    ...       ...        ...
# 497  자기계발   온라인강의      일반적인 영어 텍스트 기반 교재  매일(주 7회)      알고 있음
# 498    승진   온라인강의  비즈니스 시뮬레이션(Role Play)  매일(주 7회)      알고 있음
# 499  자기계발  오프라인강의      일반적인 영어 텍스트 기반 교재     주1-2회      알고 있음
# 500  자기계발  오프라인강의  비즈니스 시뮬레이션(Role Play)     주3-4회      알고 있음
# 501    승진  오프라인강의  비즈니스 시뮬레이션(Role Play)     주5-6회      알고 있음
#
# [502 rows x 5 columns]

# %%
data.select_dtypes(include = 'object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   학습목표         502 non-null    object
#  1   학습방법         502 non-null    object
#  2   강의 학습 교재 유형  502 non-null    object
#  3   학습빈도         502 non-null    object
#  4   취약분야 인지 여부   502 non-null    object
# dtypes: object(5)
# memory usage: 19.7+ KB

# %%
#[문제] 데이터 타입이 Object 형태인 컬럼의 컬럼명만 추출해서 출력해 보세요.

# %%
# columns.values 활용
data.select_dtypes(include = 'object').columns.values
# Out:
# array(['학습목표', '학습방법', '강의 학습 교재 유형', '학습빈도', '취약분야 인지 여부'], dtype=object)

# %% [markdown]
# #### 4) 고유값 확인 및 시각화 : 학습목표

# %%
#[문제] 변수 '학습목표'의 값들의 빈도수를 계산하여 출력하세요.

# %%
# value_counts 함수 활용
data['학습목표'].value_counts()
# Out:
# 자기계발    331
# 승진      155
# 취업       16
# Name: 학습목표, dtype: int64

# %%
#[문제] data 데이터프레임의 전체 열과 행 개수를 각각 출력해 보세요.

# %%
#열의 개수
len(data.columns)
# Out:
# 21

# %%
#행의 개수
len(data.index)
# Out:
# 502

# %%
#[문제] 변수 '학습목표'의 값들의 빈도수를 전체 데이터의 개수로 나누어서 해당 값들이 전체 데이터에서 차지하는 비율을 구하세요.

# %%
data['학습목표'].value_counts()/data['학습목표'].count()
# Out:
# 자기계발    0.659363
# 승진      0.308765
# 취업      0.031873
# Name: 학습목표, dtype: float64

# %%
#[문제] '학습목표' 컬럼에 대한 Bar 차트를 확인해주세요.

# %%
# DataFrame value_counts()와 plot() 함수 활용
# 대상 컬럼 : '학습목표'
# plot 함수의 인자 : kind='bar'
data['학습목표'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#[문제] 'data' 전체 데이터프레임의 숫자형 컬럼, number 컬럼에 대해 검색해주세요.

# %%
data.select_dtypes(include=['int','float'])
# Out:
#       ID  Gender  Birth_Year  Seq  3st_LC_Score  RC_Score_x  3st_Total_Score  \
# 0      1       1        1973    3           345         336              681
# 1      2       2        1982    3           380         368              748
# 2      3       2        1995    3           416         382              798
# 3      4       1        1987    3           495         397              892
# 4      5       1        1994    3           398         437              835
# ..   ...     ...         ...  ...           ...         ...              ...
# 497  496       1        2006    3           364         336              700
# 498  497       2        1988    3           187         252              439
# 499  498       1        2006    3           255         167              422
# 500  499       2        1990    3           422         370              792
# 501  500       1        1984    3           235         226              461
#
#      기출문제 공부 횟수  토익 모의테스트 횟수  1st_LC_Score  RC_Score_y  1st_Total_Score  \
# 0           7.0           10           181         173              354
# 1           4.0           14           330         290              620
# 2           4.0            4           367         309              676
# 3           9.0            8           470         285              755
# 4           6.0            4           273         372              645
# ..          ...          ...           ...         ...              ...
# 497        10.0           13           347         315              662
# 498         9.0           17           112         250              362
# 499         0.0            4           252         150              402
# 500         4.0            7           371         324              695
# 501         7.0           15           169         188              357
#
#      2st_LC_Score  RC_Score  2st_Total_Score  Score_diff_total
# 0             227       213              440               241
# 1             354       339              693                55
# 2             396       365              761                37
# 3             495       341              836                56
# 4             314       426              740                95
# ..            ...       ...              ...               ...
# 497           349       321              670                30
# 498           120       251              371                68
# 499           254       158              412                10
# 500           378       326              704                88
# 501           172       190              362                99
#
# [502 rows x 16 columns]

# %% [markdown]
# #### 5) 고유값 확인 및 시각화 : 강의 학습 교재 유형

# %%
#[문제] 변수 '강의 학습 교재 유형'의 값들의 빈도수, 비율을 계산해서 출력해주세요.

# %%
# 빈도수 출력
data['강의 학습 교재 유형'].value_counts()
# Out:
# 일반적인 영어 텍스트 기반 교재        137
# 영상 교재                    129
# 뉴스/이슈 기반 교재              122
# 비즈니스 시뮬레이션(Role Play)    114
# Name: 강의 학습 교재 유형, dtype: int64

# %%
# 비율 출력
data['강의 학습 교재 유형'].value_counts()/data['강의 학습 교재 유형'].count()
# Out:
# 일반적인 영어 텍스트 기반 교재        0.272908
# 영상 교재                    0.256972
# 뉴스/이슈 기반 교재              0.243028
# 비즈니스 시뮬레이션(Role Play)    0.227092
# Name: 강의 학습 교재 유형, dtype: float64

# %%
#[문제] '취약분야 인지 여부' 문자열의 값을 '알고 있음' --> '1', '알고 있지 않음' -->'0'으로 변경하세요.

# %%
data['취약분야 인지 여부'] = data['취약분야 인지 여부'].replace({'알고 있음':'1','알고 있지 않음':'0'})
data.head(5)
# Out:
#    ID  Gender  Birth_Year  Seq  3st_LC_Score  RC_Score_x  3st_Total_Score  \
# 0   1       1        1973    3           345         336              681
# 1   2       2        1982    3           380         368              748
# 2   3       2        1995    3           416         382              798
# 3   4       1        1987    3           495         397              892
# 4   5       1        1994    3           398         437              835
#
#    학습목표   학습방법        강의 학습 교재 유형  ... 기출문제 공부 횟수  취약분야 인지 여부 토익 모의테스트 횟수  \
# 0    승진  온라인강의              영상 교재  ...        7.0           1          10
# 1    승진  온라인강의        뉴스/이슈 기반 교재  ...        4.0           1          14
# 2  자기계발    참고서  일반적인 영어 텍스트 기반 교재  ...        4.0           1           4
# 3    승진  온라인강의        뉴스/이슈 기반 교재  ...        9.0           1           8
# 4  자기계발  온라인강의              영상 교재  ...        6.0           1           4
#
#    1st_LC_Score  RC_Score_y  1st_Total_Score  2st_LC_Score  RC_Score  \
# 0           181         173              354           227       213
# 1           330         290              620           354       339
# 2           367         309              676           396       365
# 3           470         285              755           495       341
# 4           273         372              645           314       426
#
#    2st_Total_Score  Score_diff_total
# 0              440               241
# 1              693                55
# 2              761                37
# 3              836                56
# 4              740                95
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 데이터 저장

# %% [markdown]
# * **세부 요구사항**
#     * to_csv를 이용하여 전처리된 데이터셋을 저장하세요.
#     * 저장할 파일의 확장자는 .csv 입니다.

# %%
#[문제] 전처리된 데이터프레임 'data04_featured'를 CSV 파일로 저장합니다.

# %%
# 파일 : 'data04_featured.csv'
# to_csv 함수 활용
data.to_csv('data04_featured_my.csv', index=False, encoding='UTF-8')

# %%
#[문제] 파일이 잘 저장되었는지, 다시 한번 불러오고 확인해보세요.

# %%
pd.read_csv('data04_featured_my.csv', encoding='UTF-8')
# Out:
#       ID  Gender  Birth_Year  Seq  3st_LC_Score  RC_Score_x  3st_Total_Score  \
# 0      1       1        1973    3           345         336              681
# 1      2       2        1982    3           380         368              748
# 2      3       2        1995    3           416         382              798
# 3      4       1        1987    3           495         397              892
# 4      5       1        1994    3           398         437              835
# ..   ...     ...         ...  ...           ...         ...              ...
# 497  496       1        2006    3           364         336              700
# 498  497       2        1988    3           187         252              439
# 499  498       1        2006    3           255         167              422
# 500  499       2        1990    3           422         370              792
# 501  500       1        1984    3           235         226              461
#
#      학습목표    학습방법            강의 학습 교재 유형  ... 기출문제 공부 횟수  취약분야 인지 여부  \
# 0      승진   온라인강의                  영상 교재  ...        7.0           1
# 1      승진   온라인강의            뉴스/이슈 기반 교재  ...        4.0           1
# 2    자기계발     참고서      일반적인 영어 텍스트 기반 교재  ...        4.0           1
# 3      승진   온라인강의            뉴스/이슈 기반 교재  ...        9.0           1
# 4    자기계발   온라인강의                  영상 교재  ...        6.0           1
# ..    ...     ...                    ...  ...        ...         ...
# 497  자기계발   온라인강의      일반적인 영어 텍스트 기반 교재  ...       10.0           1
# 498    승진   온라인강의  비즈니스 시뮬레이션(Role Play)  ...        9.0           1
# 499  자기계발  오프라인강의      일반적인 영어 텍스트 기반 교재  ...        0.0           1
# 500  자기계발  오프라인강의  비즈니스 시뮬레이션(Role Play)  ...        4.0           1
# 501    승진  오프라인강의  비즈니스 시뮬레이션(Role Play)  ...        7.0           1
#
#      토익 모의테스트 횟수  1st_LC_Score  RC_Score_y  1st_Total_Score  2st_LC_Score  \
# 0             10           181         173              354           227
# 1             14           330         290              620           354
# 2              4           367         309              676           396
# 3              8           470         285              755           495
# 4              4           273         372              645           314
# ..           ...           ...         ...              ...           ...
# 497           13           347         315              662           349
# 498           17           112         250              362           120
# 499            4           252         150              402           254
# 500            7           371         324              695           378
# 501           15           169         188              357           172
#
#      RC_Score  2st_Total_Score  Score_diff_total
# 0         213              440               241
# 1         339              693                55
# 2         365              761                37
# 3         341              836                56
# 4         426              740                95
# ..        ...              ...               ...
# 497       321              670                30
# 498       251              371                68
# 499       158              412                10
# 500       326              704                88
# 501       190              362                99
#
# [502 rows x 21 columns]

# %%
## 고생 정말 많으셨습니다!!
## 실습시간이 남으신 분은 '중급'용 파일에 도전해보세요.
